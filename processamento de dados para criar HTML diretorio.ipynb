# %% [markdown]
# # Extração de dados do excel
#
# Copiar as celulas de interesse e fazer paste para ficheiro de texto

# %%
with open('lotes.txt', encoding="utf-8") as f:
    dados = f.readlines()
    
territorios = set()

for linha in dados:
    lista_territorios = linha.split('\t')[2].split(', ')
    for territorio in lista_territorios:
        territorios.add(territorio)

territorios
# Out:
# {'Alcochete',
#  'Alentejo Central',
#  'Almada',
#  'Amadora',
#  'Barreiro',
#  'Cascais',
#  'Lisboa',
#  'Loures',
#  'Mafra',
#  'Moita',
#  'Montijo',
#  'Odivelas',
#  'Oeiras',
#  'Oeste',
#  'Palmela',
#  'Seixal',
#  'Sesimbra',
#  'Setúbal',
#  'Sintra',
#  'Vila Franca de Xira'}

# %%
diretorio = { t:{} for t in territorios }

for linha in dados:
    lista_territorios = linha.split('\t')[2].split(', ')
    for territorio in lista_territorios:
        if linha.split('\t')[4] not in diretorio[territorio]: 
            diretorio[territorio][linha.split('\t')[4]] = [(linha.split('\t')[0], linha.split('\t')[1])]
        else:
            diretorio[territorio][linha.split('\t')[4]] += [(linha.split('\t')[0], linha.split('\t')[1])]

diretorio
# Out:
# {'Palmela': {'Nova': [('3630', 'Azeitão - Penalva (Estação)'),
#    ('4303', 'Palmela | Circular'),
#    ('4304', 'Palmela (Terminal) - Penalva'),
#    ('4308', 'Palmela (Terminal) - Pinhal Novo (Estação)'),
#    ('4313', 'Cabanas - Penalva'),
#    ('4612', 'Bairro dos Marinheiros - Palmela (Terminal)')],
#   '680': [('4301', 'Palmela (Centro) - Palmela (Terminal)')],
#   '454': [('4302', 'Palmela (Estação) - Palmela (Terminal)'),
#    ('4307', 'Loja Nova - Palmela (Terminal)')],
#   '447': [('4305', 'Brejos do Assa - Palmela (Terminal)'),
#    ('4524', 'Palmela (Terminal) - Pegões')],
#   '768': [('4306', 'Cabanas - Palmela (Terminal)'),
#    ('4550', 'Palmela (Terminal) - Vila Nogueira de Azeitão')],
#   '710': [('4310', 'Águas de Moura - Poceirão')],
#   '455': [('4311', 'Asseiceira - Poceirão')],
#   '711': [('4312', 'Poceirão - Vale Abrunheira (X), via Fernando Pó')],
#   '449': [('4320', 'Pinhal Novo | Circular'),
#    ('4321', 'Pinhal Novo - Qta do Anjo')],
#   '448': [('4322', 'Pinhal Novo - Rio Frio')],
#   '413': [('4512',
#     'Alcochete (Freeport) - Setúbal (ITS), via Alto Estanqueiro'),
#    ('4513', 'Alcochete (Freeport) - Pinhal Novo'),
#    ('4517', 'Montijo (Terminal Rodoviário) - Setúbal (ITS)'),
#    ('4523', 'Montijo (Terminal Rodoviário) - Pinhal Novo')],
#   '414/416': [('4514', 'Canha - Montijo (Terminal Rodoviário), via Pegões')],
#   '416': [('4515', 'Montijo (Terminal Rodoviário) - Pegões')],
#   '426': [('4516', 'Montijo (Terminal Rodoviário) - Rio Frio')],
#   '444': [('4520', 'Faias - Pegões')],
#   '446': [('4521', 'Faias - Pinhal Novo'), ('4522', 'Faias - Poceirão')],
#   '451': [('4530', 'Bairro Vila Morena - Pinhal Novo')],
#   '326 (Adaptado)': [('4531', 'Moita - Palmela (Terminal)')],
#   '313 (Adaptado)': [('4532', 'Moita - Quatro Marcos')],
#   '764/765': [('4540', 'Águas de Moura - Setúbal (ITS)'),
#    ('4544', 'Bairro Margaça - Setúbal (ITS)')],
#   '610': [('4541', 'Algeruz - Setúbal (Av. Luísa Todi)')],
#   '779': [('4542', 'Algeruz - Setúbal (ITS)'),
#    ('4543', 'Algeruz - Setúbal (ITS), via Poçoilos')],
#   '708': [('4545', 'Biscainho - Setúbal (Bela Vista)')],
#   '774': [('4546', 'Biscainho - Setúbal (ITS)')],
#   '767': [('4547', 'Cabanas - Setúbal (ITS)'),
#    ('4549', 'Palmela (Terminal) - Setúbal (ITS)')],
#   '758': [('4548', 'Lagameças - Setúbal (ITS)')],
#   '604': [('4551', 'Palmela (USF) - Setúbal (Av. Luísa Todi)')],
#   '257': [('4560', 'Cabanas - Vila Nogueira de Azeitão'),
#    ('4561', 'Cabanas - Vila Nogueira de Azeitão, via Quinta do Picão')],
#   '767/768': [('4562',
#     'Setúbal (ITS) - Vila Nogueira de Azeitão, via Palmela (Estação)')],
#   '305': [('4610', 'Bairro dos Marinheiros - Barreiro (Terminal)')],
#   '311 (Adaptado)': [('4611', 'Penalva - Moita (Esc. Secundária)')],
#   '565': [('4710', 'Lisboa (Oriente) - Palmela (Terminal)'),
#    ('4711', 'Lisboa (Oriente) - Pinhal Novo')],
#   '563': [('4715', 'Lisboa (Oriente) - Setúbal (ITS), via Pinhal Novo')],
#   '709': [('4901', 'Landeira - Setúbal (ITS)')],
#   '8902': [('4902', 'Landeira - Pegões'),
#    ('4906', 'Setúbal (ITS) - Vendas Novas, via Landeira')],
#   '8080': [('4905', 'Pegões - Vendas Novas')]},
#  'Montijo': {'453': [('4201', 'Afonsoeiro - Bairro da Liberdade'),
#    ('4706', 'São Francisco - Lisboa (Oriente)')],
#   '404': [('4202', 'Afonsoeiro - Bairro do Saldanha, via Bairro da Calçada')],
#   '403': [('4203',
#     'Afonsoeiro - Montijo (Terminal Fluvial), via Bairro da Liberdade'),
#    ('4206', 'Bairro Esteval - Montijo (Terminal Fluvial)')],
#   '401': [('4204', 'Bairro do Charqueirão - Montijo (Terminal Fluvial)'),
#    ('4205',
#     'Bairro do Charqueirão - Montijo (Terminal Fluvial), via Vale Porim'),
#    ('4207', 'Montijo (Área Comercial) - Montijo (Terminal Fluvial)')],
#   'Nova': [('4208',
#     'Montijo (Terminal Rodoviário) - Sarilhos Grandes (Estr. 4 Marcos)'),
#    ('4211', 'Craveiras - Pegões | Circular'),
#    ('4501', 'Alcochete - Montijo (Terminal Fluvial)'),
#    ('4503', 'Atalaia - Jardia')],
#   '441': [('4210', 'Canha - Foros Boavista'),
#    ('4212', 'Foros Boavista - Pegões')],
#   '419': [('4502', 'Alcochete - Passil')],
#   '415': [('4504', 'Montijo (Terminal Fluvial) - Passil')],
#   '413': [('4510', 'Alcochete (Freeport) - Montijo (Terminal Rodoviário)'),
#    ('4512', 'Alcochete (Freeport) - Setúbal (ITS), via Alto Estanqueiro'),
#    ('4513', 'Alcochete (Freeport) - Pinhal Novo'),
#    ('4517', 'Montijo (Terminal Rodoviário) - Setúbal (ITS)'),
#    ('4523', 'Montijo (Terminal Rodoviário) - Pinhal Novo')],
#   '410': [('4511',
#     'Alcochete (Freeport) - Montijo (Terminal Rodoviário), via Samouco'),
#    ('4600', 'Alcochete (Freeport) - Barreiro (Terminal)'),
#    ('4601', 'Barreiro (Terminal) - Montijo (Terminal Rodoviário)')],
#   '414/416': [('4514', 'Canha - Montijo (Terminal Rodoviário), via Pegões')],
#   '416': [('4515', 'Montijo (Terminal Rodoviário) - Pegões')],
#   '426': [('4516', 'Montijo (Terminal Rodoviário) - Rio Frio')],
#   '444': [('4520', 'Faias - Pegões')],
#   '446': [('4521', 'Faias - Pinhal Novo'), ('4522', 'Faias - Poceirão')],
#   '447': [('4524', 'Palmela (Terminal) - Pegões')],
#   '451': [('4530', 'Bairro Vila Morena - Pinhal Novo')],
#   '440': [('4643', 'Montijo (Av. Inf. D. Henrique) - Sesimbra (Terminal)')],
#   '333': [('4701', 'Lisboa (Oriente) - Vale da Amoreira')],
#   '431': [('4703',
#     'Lisboa (Oriente) - Montijo (Terminal Rodoviário), via Alcochete e Samouco')],
#   '432': [('4704', 'Atalaia - Lisboa (Oriente)')],
#   '435': [('4705', 'Lisboa (Oriente) - Samouco'),
#    ('4707', 'Lisboa (Oriente) - Montijo (Terminal Rodoviário)')],
#   '8902': [('4902', 'Landeira - Pegões'),
#    ('4906', 'Setúbal (ITS) - Vendas Novas, via Landeira')],
#   '8080': [('4905', 'Pegões - Vendas Novas')]},
#  'Alcochete': {'Nova': [('4001', 'Alcochete | Circular'),
#    ('4002', 'São Francisco | Circular'),
#    ('4501', 'Alcochete - Montijo (Terminal Fluvial)'),
#    ('4503', 'Atalaia - Jardia')],
#   '419': [('4502', 'Alcochete - Passil')],
#   '415': [('4504', 'Montijo (Terminal Fluvial) - Passil')],
#   '413': [('4510', 'Alcochete (Freeport) - Montijo (Terminal Rodoviário)'),
#    ('4512', 'Alcochete (Freeport) - Setúbal (ITS), via Alto Estanqueiro'),
#    ('4513', 'Alcochete (Freeport) - Pinhal Novo')],
#   '410': [('4511',
#     'Alcochete (Freeport) - Montijo (Terminal Rodoviário), via Samouco'),
#    ('4600', 'Alcochete (Freeport) - Barreiro (Terminal)')],
#   '414/416': [('4514', 'Canha - Montijo (Terminal Rodoviário), via Pegões')],
#   '416': [('4515', 'Montijo (Terminal Rodoviário) - Pegões')],
#   '426': [('4516', 'Montijo (Terminal Rodoviário) - Rio Frio')],
#   '432': [('4702', 'Lisboa (Oriente) - Valbom'),
#    ('4704', 'Atalaia - Lisboa (Oriente)')],
#   '431': [('4703',
#     'Lisboa (Oriente) - Montijo (Terminal Rodoviário), via Alcochete e Samouco')],
#   '435': [('4705', 'Lisboa (Oriente) - Samouco')],
#   '453': [('4706', 'São Francisco - Lisboa (Oriente)')]},
#  'Vila Franca de Xira': {'53': [('2301', 'Alhandra - Bogalhão'),
#    ('2308', 'Bogalhão - Vila Franca de Xira (Terminal)'),
#    ('2309', 'Bogalhão - Vila Franca de Xira (Terminal), via Subserra'),
#    ('2330', 'Subserra - Vila Franca de Xira (Terminal)')],
#   '40/48': [('2302', 'Alverca - Vila Franca de Xira (Terminal)')],
#   '153': [('2303', 'Alverca (Estação) - Arcena')],
#   '57': [('2304', 'Alverca (Estação) - Bulhaco')],
#   'Nova': [('2305', 'Alverca (Estação) - Malvarosa | Circular'),
#    ('2315', 'Castanheira do Ribatejo | Circular'),
#    ('2322', 'Bolonha - Póvoa de Santa Iria (Estação)'),
#    ('2534', 'Loures - Santa Iria da Azóia'),
#    ('2535', 'Loures - Vila Franca de Xira'),
#    ('2539',
#     'Sacavém (Estação) - Santa Iria da Azóia (Estação), via Portela da Azóia'),
#    ('2540', 'Santa Iria da Azóia - Vialonga'),
#    ('2842', 'Lisboa (C. Grande) - Vila Franca de Xira')],
#   '44': [('2306', 'Alverca (Estação) - Vila Franca de Xira (Terminal)')],
#   '39': [('2307', 'Arcena - Vila Franca de Xira (Terminal)')],
#   '14': [('2310', 'Bom Retiro - Carregado (Atral-CIPAN)'),
#    ('2313', 'Carregado (Atral-CIPAN) - Vila Franca de Xira (Estação)'),
#    ('2314', 'Castanheira do Ribatejo - Vila Franca de Xira (Estação)')],
#   '19': [('2311', 'Cachoeiras - Castanheira do Ribatejo'),
#    ('2312', 'Cachoeiras - Vila Franca de Xira (Terminal)'),
#    ('2320', 'Monte Gordo - Vila Franca de Xira (Estação)'),
#    ('2321', 'Monte Gordo - Vila Franca de Xira (Terminal)'),
#    ('2927', 'Cadafais - Vila Franca de Xira (Terminal), via Loja Nova')],
#   '50': [('2316', 'Cotovios - Vila Franca de Xira (Terminal)')],
#   '349': [('2317', 'Fonte Santa - Póvoa de Santa Iria (Estação), via Morgado'),
#    ('2326', 'Póvoa de Santa Iria (Estação) - Vialonga')],
#   '323': [('2318',
#     'Forte da Casa - Póvoa de Santa Iria (Estação) | Circular')],
#   '322': [('2319', 'Forte da Casa | Circular')],
#   '324/326/328': [('2323', 'Póvoa de Santa Iria | Circular')],
#   '40/41': [('2324', 'Póvoa de Santa Iria - Vila Franca de Xira (Terminal)')],
#   '350': [('2325', 'Póvoa de Santa Iria (Estação) - Verdelho Ruivo')],
#   '351': [('2327', 'Póvoa de Santa Iria (Estação) - Vialonga | Circular')],
#   '40': [('2328',
#     'Póvoa de Santa Iria (Qta Piedade) - Vila Franca de Xira (Terminal)')],
#   '45': [('2329', 'Qta da Cruz de Pau - Sobralinho')],
#   '49': [('2331',
#     'Torre de Cima e Capelas - Vila Franca de Xira (Hospital), via Povos'),
#    ('2332', 'Vila Franca de Xira (Estação) - Vila Franca de Xira (Hospital)'),
#    ('2333',
#     'Vila Franca de Xira (Estação) - Vila Franca de Xira (Hospital), via N1')],
#   '342': [('2530', 'Alverca (Estação) - Bucelas, via Malvarosa')],
#   '346': [('2531', 'Alverca (Estação) - Granja, via Casal das Areias'),
#    ('2533', 'Alverca (Estação) - Santo Antão do Tojal, via Casal das Areias')],
#   '360': [('2532', 'Alverca (Estação) - Loures')],
#   '325': [('2536', 'Póvoa de Santa Iria - Salvação | Circular')],
#   '348/370': [('2537',
#     'Póvoa de Santa Iria (Estação) - Santo Antão do Tojal')],
#   '370': [('2538',
#     'Póvoa de Santa Iria (Estação) - Santo Antão do Tojal, via Zambujal')],
#   '355': [('2651', 'Bucelas - Costa da Caparica (Terminal)')],
#   '701': [('2652', 'Costa da Caparica (Terminal) - Forte da Casa')],
#   '320': [('2790', 'Alverca (Estação) - Lisboa (C. Grande)'),
#    ('2793', 'Forte da Casa - Lisboa (C. Grande)')],
#   '319': [('2791', 'Alverca (Z. Industrial) - Lisboa (C. Grande)')],
#   '347': [('2792', 'Arcena - Lisboa (Oriente)'),
#    ('2840', 'Arcena - Lisboa (Oriente), via A1')],
#   '330': [('2794', 'Forte da Casa - Lisboa (Oriente)')],
#   '329': [('2795', 'Lisboa (C. Grande) - Quinta da Piedade')],
#   '354': [('2796', 'Lisboa (C. Grande) - Vialonga')],
#   '353': [('2797', 'Lisboa (C. Grande) - Vialonga, via A8'),
#    ('2798', 'Lisboa (C. Grande) - Vialonga, via A9 e A8')],
#   '72': [('2841', 'Lisboa (C. Grande) - Sobralinho')],
#   '58': [('2920', 'A-do-Mourão - Alverca (Estação)')],
#   '59': [('2921', 'Alhandra - Arruda dos Vinhos'),
#    ('2922', 'Arruda dos Vinhos - Bulhaco')],
#   '18': [('2925',
#     'Cadafais - Vila Franca de Xira (Terminal), via Bairro da Mata'),
#    ('2926', 'Cadafais - Vila Franca de Xira (Terminal), via Cachoeiras')],
#   '16': [('2928', 'Casais da Granja - Vila Franca de Xira (Estação)')]},
#  'Sesimbra': {'201': [('3205', 'Cabo Espichel - Sesimbra (Terminal)'),
#    ('3203', 'Azoia - Sesimbra (Terminal)'),
#    ('3204', 'Azoia - Sesimbra (Terminal), via Serra da Azoia')],
#   '203': [('3206', 'Carrasqueira - Sesimbra (Terminal)'),
#    ('3536', 'Cacilhas (Terminal) - Sesimbra (Terminal)')],
#   '210': [('3217', 'Azoia - Sampaio')],
#   '221': [('3220', 'Sesimbra | Circular')],
#   '222': [('3209', 'Fornos - Sesimbra (Terminal), via Aiana'),
#    ('3201', 'Aldeia do Meco - Sesimbra (Terminal), via Aiana'),
#    ('3202', 'Alfarim - Sesimbra (Terminal), via Aiana')],
#   '223': [('3208', 'Fetais - Sesimbra (Terminal)')],
#   '227': [('3212', 'Maçã (Rua Macieira) - Sesimbra (Terminal)'),
#    ('3216', 'Alto das Vinhas - Sampaio')],
#   '228': [('3218', 'Sesimbra (Porto de Abrigo) - Sesimbra (Terminal)')],
#   '229': [('3213', 'Pinhal de Cima - Sesimbra (Terminal) | Circular')],
#   '234': [('3215', 'Fornos - Sampaio')],
#   '240': [('3211', 'Lagoa de Albufeira - Sesimbra (Terminal), via Sampaio'),
#    ('3210', 'Lagoa de Albufeira - Sesimbra (Terminal)')],
#   '243': [('3207', 'Carrasqueira - Sesimbra (Terminal), via Valbom e Sampaio'),
#    ('3221', 'Valbom - Sesimbra (Terminal), via Sampaio')],
#   '247': [('3214', 'Sampaio - Santana')],
#   'Nova': [('3219', 'Sesimbra (R. Palames) - Sesimbra (Terminal)'),
#    ('3222', 'Quinta do Conde | Circular'),
#    ('3540', 'Alfarim - Coina (Estação)'),
#    ('3542', 'Coina (Estação) - Praia do Meco'),
#    ('3544', 'Coina (Estação) - Sesimbra (Terminal)'),
#    ('3541',
#     'Coina (Estação) - Fernão Ferro, via Casal do Sapo e Pinhal do General'),
#    ('3630', 'Azeitão - Penalva (Estação)'),
#    ('3625', 'Barreiro - Sesimbra (Terminal)')],
#   '211': [('3549',
#     'Quinta do Conde - Sesimbra (Terminal), via Sampaio e Marco do Grilo')],
#   '219': [('3548', 'Marco do Grilo - Quinta do Conde')],
#   '254': [('3535', 'Cacilhas (Terminal) - Quinta do Conde'),
#    ('3547', 'Fogueteiro (Estação) - Quinta do Conde'),
#    ('3546', 'Cruz de Pau - Quinta do Conde')],
#   '260': [('3545', 'Corroios (Estação) - Sesimbra (Terminal)')],
#   '2ND': [('3543', 'Coina (Estação) - Quinta do Conde, via Estrada de Coina')],
#   '208': [('3641', 'Quinta do Conde - Sampaio, via Azeitão'),
#    ('3635', 'Coina (Estação) - Sesimbra (Terminal), via Azeitão e Sampaio')],
#   '225': [('3640', 'Azoia - Vila Nogueira de Azeitão')],
#   '245': [('3650', 'Moita - Sesimbra (Terminal)')],
#   '2N': [('3626', 'Coina (Estação) - Vila Fresca de Azeitão')],
#   '783': [('3605', 'Cacilhas (Terminal) - Setúbal (ITS), via Azeitão')],
#   '1N': [('3620', 'Coina (Estação) - Quinta do Conde')],
#   '207': [('3721', 'Lisboa (Sete Rios) - Sesimbra (Terminal)')],
#   '252': [('3720', 'Lisboa (Sete Rios) - Quinta do Conde')],
#   '755': [('4630', 'Corroios (Estação) - Setúbal (ITS)')],
#   '754': [('4631', 'Fogueteiro (Estação) - Setúbal (ITS)')],
#   '259': [('4640', 'Casais da Serra - Vila Nogueira de Azeitão')],
#   '770': [('4641', 'Quinta do Conde - Setúbal (ITS)')],
#   '230': [('4642', 'Sesimbra (Terminal) - Setúbal (Hospital)')],
#   '440': [('4643', 'Montijo (Av. Inf. D. Henrique) - Sesimbra (Terminal)')]},
#  'Oeiras': {'1': [('1101', 'Alfragide (Alegro) - Algés (Terminal)'),
#    ('1504', 'Algés (Terminal) - Bairro Zambujal, via Linda-a-Velha'),
#    ('1722', 'Alfragide (Alegro) - Hospital São Francisco Xavier')],
#   'Nova': [('1102', 'Algés - Cruz Quebrada'),
#    ('1109', 'Carnaxide-Outurela'),
#    ('1110', 'Carnaxide-Queijas'),
#    ('1111', 'Barcarena | Circular'),
#    ('1121', 'Oeiras | Circular'),
#    ('1122', 'Paço de Arcos - Caxias'),
#    ('1125', 'Porto Salvo | Circular'),
#    ('1501', 'Alfragide - Reboleira (Estação) | Circular'),
#    ('1506', 'Amadora Hospital | Circular, via Alfragide'),
#    ('1520', 'Algés (Terminal) - Cacém (Estação)'),
#    ('1521', 'Algés (Terminal) - Cacém (Estação), via A5'),
#    ('1605', 'Carnaxide (Av. João Paulo II) - Nova SBE'),
#    ('1606', 'Carnaxide (Av. João Paulo II) - Nova SBE, via Terrugem'),
#    ('1612', 'Cacém (Estação) - Carcavelos (Estação)'),
#    ('1731', 'Cacém (Estação) - Hospital São Francisco Xavier')],
#   '2': [('1103', 'Algés (Terminal) - Queijas'),
#    ('1107', 'Algés (Terminal) - Queluz Baixo, via Queijas')],
#   '6': [('1104', 'Algés (Terminal) - Queijas, via Jamor'),
#    ('1106', 'Algés (Terminal) - Queluz Baixo, via Jamor')],
#   '12': [('1105', 'Algés (Terminal) - Queluz Baixo'),
#    ('1108', 'Carnaxide (Escola) - Queluz Baixo'),
#    ('1522', 'Algés (Terminal) - Monte Abraão (Estação)')],
#   '108': [('1112', 'Caxias - Queijas'),
#    ('1507', 'Caxias - Reboleira (Metro)')],
#   '158': [('1113', 'Caxias (Estação) - Lage'),
#    ('1114', 'Caxias (Estação) - Paço de Arcos (Estação)'),
#    ('1115', 'Caxias (Pedreira Italiana) - Lage'),
#    ('1116', 'Caxias (Pedreira Italiana) - Paço de Arcos (Estação)'),
#    ('1117', 'Caxias (Quinta da Moura) - Lage'),
#    ('1118', 'Caxias (Quinta da Moura) - Paço de Arcos (Estação)')],
#   '119': [('1119', 'Leceia - Paço de Arcos (Estação)'),
#    ('1531', 'Paço de Arcos (Estação) - São Marcos'),
#    ('1617', 'Paço de Arcos (Estação) - Talaíde (Igreja)')],
#   '111': [('1120', 'Oeiras (Estação) - Paço de Arcos (Estação)')],
#   '129': [('1123', 'Paço de Arcos (Estação) - Porto Salvo (Lagoas Park)')],
#   '116': [('1124', 'Paço de Arcos | Circular')],
#   '114': [('1502',
#     'Algés (Terminal) - Amadora (Estação Sul), via Linda-a-Velha')],
#   '10': [('1503', 'Algés (Terminal) - Bairro Zambujal'),
#    ('1505', 'Algés (Terminal) - IKEA Alfragide')],
#   '112': [('1523', 'Cacém (Estação) - Oeiras (Estação)')],
#   '23': [('1524',
#     'Casal do Cotão | Circular, via Tercena, São Marcos e Taguspark')],
#   '117': [('1525', 'Caxias - Monte Abraão (Estação)'),
#    ('1526', 'Caxias (Est. Prisional) - Monte Abraão (Estação)')],
#   '102': [('1527', 'Cruz Quebrada (Estação) - Queluz (Estação)')],
#   '171': [('1528', 'Miraflores (Esc. Secundária) - Queluz (Estação)')],
#   '122': [('1529', 'Oeiras (Estação) - Bairros dos Navegadores')],
#   '106': [('1530', 'Oeiras (Estação) - Queluz'),
#    ('1601', 'Amadora Este (Metro) - Carcavelos (Praia)'),
#    ('1602', 'Carcavelos (Praia) - Queluz')],
#   '471': [('1604', 'Carcavelos (Estação) - Parede (Terminal)')],
#   '470': [('1607', 'Conceição da Abóboda - Oeiras (Estação)'),
#    ('1608', 'Oeiras (Estação) - Taguspark'),
#    ('1609', 'Oeiras (Estação) - Talaíde (Igreja)')],
#   '125': [('1610', 'Paço de Arcos (Estação) - Talaíde (Campo de Futebol)'),
#    ('1616', 'Paço de Arcos (Estação) - Taguspark')],
#   '184': [('1611',
#     'Paço de Arcos (Estação) - Talaíde (Campo de Futebol), via Vila Fria')],
#   '463': [('1613', 'Cacém (Estação) - Oeiras (Estação), via Trajouce')],
#   '467': [('1614', 'Carcavelos (Estação) - Portela de Sintra (Estação)')],
#   '468': [('1615', 'Carcavelos (Estação) - Rio de Mouro (Estação)')],
#   '20': [('1712', 'Algés (Terminal) - Amadora (Estação Sul)')],
#   '162': [('1713', 'Algés (Terminal) - Amadora Este (Metro)')],
#   '113': [('1714', 'Amadora (Estação Sul) - Belém (Estação)')],
#   '149': [('1715', 'Belém (Estação) - Mira Sintra (Mercado)')],
#   '107': [('1716', 'Idanha - Lisboa (M. Pombal)')],
#   '101': [('1717', 'Lisboa (C. Militar) - Tercena, via Amadora Este (Metro)')],
#   '7/13': [('1723', 'Carnaxide - Lisboa (M. Pombal)')],
#   '11': [('1724', 'Linda-a-Velha - Lisboa (M. Pombal)')],
#   '115': [('1725', 'Lisboa (M. Pombal) - Oeiras (Estação)')],
#   '13': [('1726', 'Lisboa (M. Pombal) - Queijas'),
#    ('1728', 'Lisboa (M. Pombal) - Queijas, via Linda-a-Velha'),
#    ('1730', 'Lisboa (M. Pombal) - Queluz Baixo, via Linda-a-Velha')],
#   '13D/15': [('1727', 'Lisboa (M. Pombal) - Queijas, via A5')],
#   '13D': [('1729', 'Lisboa (M. Pombal) - Queluz Baixo (C.C.)')],
#   '15': [('1732', 'Lisboa (M. Pombal) - São Marcos, via Carnaxide'),
#    ('1733', 'Lisboa (M. Pombal) - São Marcos, via Linda-a-Pastora')]},
#  'Seixal': {'108': [('3103', 'Corroios (Estação) - Paio Pires (Farinheiras)')],
#   '112': [('3114', 'Foros de Amora - Paio Pires (Quinta Flamância)')],
#   '116': [('3102', 'Aroeira - Paio Pires (Quinta Flamância)'),
#    ('3122', 'Verdizela - Cruz de Pau'),
#    ('3521', 'Cruz de Pau - Fonta da Telha'),
#    ('3523',
#     'Fonte da Telha - Paio Pires (Quinta Flamância), via Seixal (Terminal Fluvial) e Foros de Amora (Estação)')],
#   '137': [('3120', 'Redondos - Seixal (Terminal Fluvial)'),
#    ('3110', 'Fogueteiro (Estação) - Redondos')],
#   '184': [('3111', 'Fogueteiro (Estação) - Seixal (Terminal Fluvial)')],
#   '195': [('3119', 'Pinhal Conde Cunha - Seixal (Terminal Fluvial)')],
#   '236': [('3107', 'Laranjeiras - Marco do Grilo')],
#   '1A': [('3101', 'Amora - Foros de Amora (Estação)')],
#   '2A': [('3108', 'Fogueteiro - Foros de Amora (Estação)')],
#   '1F': [('3112',
#     'Fogueteiro (Estação) - Seixal (Terminal Fluvial), via Paio Pires')],
#   '2F': [('3113',
#     'Fogueteiro (Estação) - Seixal (Terminal Fluvial), via Quinta do Cabral')],
#   '3F': [('3105', 'Fernão Ferro - Fogueteiro (Estação)')],
#   '4F': [('3109', 'Fogueteiro (Estação) - Parque Empresarial do Seixal')],
#   'Nova': [('3121', 'Seixal | Circular'),
#    ('3106', 'Coina (Estação) - Fernão Ferro'),
#    ('3116', 'Marisol - Seixal (Terminal Fluvial), via Corroios (Estação)'),
#    ('3115', 'Marisol - Foros de Amora (Estação), via Corroios (Estação)'),
#    ('3118', 'Marisol (Valadares) - Seixal (Terminal Fluvial)'),
#    ('3117', 'Marisol (Valadares) - Foros de Amora (Estação)'),
#    ('3525', 'Hospital Garcia de Orta - Miratejo'),
#    ('3505', 'Cacilhas (Terminal) - Corroios (Estação)'),
#    ('3503', 'Almada Forum - Vale de Milhaços'),
#    ('3540', 'Alfarim - Coina (Estação)'),
#    ('3542', 'Coina (Estação) - Praia do Meco'),
#    ('3544', 'Coina (Estação) - Sesimbra (Terminal)'),
#    ('3541',
#     'Coina (Estação) - Fernão Ferro, via Casal do Sapo e Pinhal do General'),
#    ('3615', 'Barreiro - Seixal'),
#    ('3625', 'Barreiro - Sesimbra (Terminal)'),
#    ('3601', 'Barreiro - Cova da Piedade (Metro)'),
#    ('4621', 'Moita - Seixal (Terminal Fluvial)')],
#   '110': [('3513', 'Cacilhas (Terminal) - Santa Marta do Pinhal')],
#   '114': [('3508', 'Cacilhas (Terminal) - Paio Pires (Centro)')],
#   '120': [('3515', 'Caparica (Pilotos) -  Corroios')],
#   '121': [('3526', 'Laranjeiro - Pinheirinho')],
#   '139': [('3519', 'Costa da Caparica (Terminal) - Corroios (Estação)')],
#   '143': [('3518', 'Corroios (Estação) - Vale de Figueira')],
#   '149': [('3512', 'Cacilhas (Terminal) - Quinta Princesa')],
#   '159': [('3501', 'Almada Forum - Marisol, via Sobreda'),
#    ('3716', 'Lisboa (Sete Rios) - Marisol')],
#   '163': [('3520', 'Costa da Caparica (Terminal) - Quinta do Brasileiro')],
#   '172': [('3522', 'Fonte da Telha - Paio Pires (Centro)')],
#   '191': [('3514', 'Cacilhas (Terminal) - Vale de Milhaços')],
#   '192': [('3511', 'Cacilhas (Terminal) - Pinheirinho')],
#   '196': [('3510', 'Cacilhas (Terminal) - Pilotos')],
#   '198': [('3502', 'Almada Forum - Paio Pires (Centro)'),
#    ('3527', 'Monte da Caparica (FCT) - Paio Pires (Bairro Cucena)'),
#    ('3528', 'Monte da Caparica (FCT) - Paio Pires (Centro)')],
#   '199': [('3509',
#     'Cacilhas (Terminal) - Paio Pires (Centro), via Seixal (Terminal Fluvial) e Amora')],
#   '203': [('3536', 'Cacilhas (Terminal) - Sesimbra (Terminal)')],
#   '211': [('3549',
#     'Quinta do Conde - Sesimbra (Terminal), via Sampaio e Marco do Grilo')],
#   '219': [('3548', 'Marco do Grilo - Quinta do Conde')],
#   '254': [('3535', 'Cacilhas (Terminal) - Quinta do Conde'),
#    ('3547', 'Fogueteiro (Estação) - Quinta do Conde'),
#    ('3546', 'Cruz de Pau - Quinta do Conde')],
#   '260': [('3545', 'Corroios (Estação) - Sesimbra (Terminal)')],
#   '1C': [('3516', 'Charneca da Caparica - Corroios (Estação)')],
#   '3C': [('3517', 'Chegadinho - Corroios (Estação)')],
#   '126 (Adaptado)': [('3507', 'Cacilhas (Terminal) - Marisol'),
#    ('3524', 'Hospital Garcia de Orta - Marisol')],
#   '2C (Adaptado)': [('3506',
#     'Cacilhas (Terminal) - Corroios (Estação), via Miratejo')],
#   '197': [('3504', 'Bairro Fundo Fomento - Quintinha')],
#   '2ND': [('3543', 'Coina (Estação) - Quinta do Conde, via Estrada de Coina')],
#   '208': [('3635',
#     'Coina (Estação) - Sesimbra (Terminal), via Azeitão e Sampaio')],
#   '2N': [('3626', 'Coina (Estação) - Vila Fresca de Azeitão')],
#   '583': [('3610', 'Cacilhas (Terminal) - Setúbal (ITS), via A2')],
#   '783': [('3605', 'Cacilhas (Terminal) - Setúbal (ITS), via Azeitão')],
#   '1N': [('3620', 'Coina (Estação) - Quinta do Conde')],
#   '162': [('3717', 'Lisboa (Sete Rios) - Quinta do Brasileiro')],
#   '169': [('3715', 'Lisboa (M. Pombal) - Santa Marta do Pinhal')],
#   '207': [('3721', 'Lisboa (Sete Rios) - Sesimbra (Terminal)')],
#   '252': [('3720', 'Lisboa (Sete Rios) - Quinta do Conde')],
#   '302': [('4620', 'Moita - Paio Pires')],
#   '755': [('4630', 'Corroios (Estação) - Setúbal (ITS)')],
#   '754': [('4631', 'Fogueteiro (Estação) - Setúbal (ITS)')]},
#  'Sintra': {'253': [('1201',
#     'Alcolombal de Cima - Terrugem (Escola), via Sacário')],
#   '460': [('1202', 'Alegro Sintra - Mem Martins | Circular'),
#    ('1203', 'Alegro Sintra - Rio de Mouro (Estação)'),
#    ('1207', 'Algueirão-Mem Martins (Estação) - Rio de Mouro (Estação)'),
#    ('1251', 'Portela de Sintra (Estação) - Rio de Mouro (Estação)')],
#   '152': [('1204', 'Alegro Sintra | Circular')],
#   '458': [('1205',
#     'Algueirão-Mem Martins (Estação) - Mem Martins (Esc. Secundária)')],
#   '437': [('1206',
#     'Algueirão-Mem Martins (Estação) - Portela de Sintra (Estação), via Tribunal')],
#   '447': [('1208',
#     'Almargem do Bispo (Cemitério) - Portela de Sintra (Estação)'),
#    ('1235', 'Covas de Ferro - Mercês (Estação)')],
#   '160': [('1209', 'Bairro da Felosa - Mira Sintra (Mercado)')],
#   '450': [('1210', 'Bairro Fitares - Mem Martins (Esc. Secundária)')],
#   '112': [('1211', 'Belas - Cacém (Estação)'),
#    ('1523', 'Cacém (Estação) - Oeiras (Estação)')],
#   '179': [('1212', 'Cacém (Bairro Grajal) - Queluz (Estação)')],
#   '150': [('1213',
#     'Cacém (Bairro Joaquim Fontes - Shopping) - Cacém (Estação)')],
#   '448': [('1214', 'Cacém (Estação) - Alegro Sintra'),
#    ('1223', 'ShopBus Cacém')],
#   '170': [('1215', 'Cacém (Estação) - Encosta de São Marcos'),
#    ('1217', 'Cacém (Estação) - Massamá (Urbanização Norte)'),
#    ('1225', 'Encosta de São Marcos - Massamá (Urbanização Norte)')],
#   '22': [('1216', 'Casal do Cotão | Circular, via Tercena e São Marcos')],
#   '151': [('1218', 'Cacém (Estação) - Mira Sintra (Mercado)'),
#    ('1219', 'Cacém (Estação) - Mira Sintra (Mercado), via Av. Santa Maria')],
#   '140': [('1220', 'Cacém (Estação) - São Marcos (Largo)'),
#    ('1233', 'Mira Sintra (Mercado) - São Marcos (Largo)')],
#   '126': [('1221', 'Cacém (Estação) | Circular')],
#   '161': [('1222', 'Cacém (Estação) | Circular, via Bairro Joaquim Fontes')],
#   '164': [('1224',
#     'Carregueira (Estabelecimento prisional) - Monte Abraão (Estação)')],
#   '24': [('1226', 'Massamá - Queluz (Estação)')],
#   '163': [('1227', 'Massamá (Casal do Olival) - Queluz'),
#    ('1721',
#     'Lisboa (C. Militar) - Massamá (Casal do Olival), via Amadora Este (Metro)')],
#   'Nova': [('1228', 'Massamá (Estação) | Circular, via Belas'),
#    ('1232', 'Rio de Mouro (Estação) | Circular, via Mem Martins'),
#    ('1242', 'Cabrela - Várzea de Colares'),
#    ('1244', 'Casal de Cambra - Portela de Sintra (Estação)'),
#    ('1509', 'Amadora (Hospital) - Casal de Cambra (C. Saúde)'),
#    ('1516', 'Casal de Cambra - Monte Abraão (Estação)'),
#    ('1520', 'Algés (Terminal) - Cacém (Estação)'),
#    ('1521', 'Algés (Terminal) - Cacém (Estação), via A5'),
#    ('1612', 'Cacém (Estação) - Carcavelos (Estação)'),
#    ('1719', 'Casal de Cambra - Lisboa (C. Militar)'),
#    ('1731', 'Cacém (Estação) - Hospital São Francisco Xavier'),
#    ('2625', 'Mafra - São João das Lampas')],
#   '110': [('1229',
#     'Urbanização Quinta das Flores (Junta de Freguesia) | Circular')],
#   '130/131': [('1230', 'Monte Abraão (Estação) | Circular')],
#   '257': [('1231', 'Mem Martins (Esc. Ferreira Castro) - Coutinho Afonso')],
#   '446': [('1234', 'ShopBus Mira Sintra')],
#   '255': [('1240', 'Negrais - Portela de Sintra (Estação)')],
#   '441': [('1241',
#     'Almoçageme (Av. Dr. B. Vasc. X R. Sto André) - Portela de Sintra (Estação)')],
#   '445': [('1243', 'Casais da Cabrela - Portela de Sintra (Estação)'),
#    ('1632', 'Carvalhal - Portela de Sintra (Estação)')],
#   '443': [('1245', 'Catribana - Portela de Sintra (Estação)')],
#   '442': [('1246',
#     'Fontanelas - Portela de Sintra (Estação), via Casal da Granja'),
#    ('1248', 'Portela de Sintra (Estação) - Praia das Maçãs (Piscinas)')],
#   '440 (Adaptado)': [('1247',
#     'Fontanelas - Portela de Sintra (Estação), via Janas')],
#   '444': [('1249', 'Portela de Sintra (Estação) - Praia do Magoito')],
#   '439 (Adaptado)': [('1250', 'Portela de Sintra (Estação) - Praia Grande')],
#   '433': [('1252', 'Portela de Sintra (Estação) | Circular')],
#   '435 (Adaptado)': [('1253', 'Circuito Cabo da Roca - Portela de Sintra')],
#   '441 (Adaptado)': [('1254', 'Circuito Praias - Portela de Sintra')],
#   '254': [('1255', 'Rebanque - Portela de Sintra (Estação)')],
#   '104': [('1508', 'Almargem do Bispo - Amadora Este (Metro)')],
#   '186 (Adaptado)': [('1510',
#     'Amadora (Hospital) - Damaia (Praceta Liberdade)')],
#   '149/Nova': [('1511', 'Amadora (Hospital) - Monte Abraão (Estação)')],
#   '103': [('1512', 'Amadora (Hospital) - Montelavar')],
#   '25': [('1513', 'Amadora (Hospital) | Circular')],
#   '154/155 (Adaptado)': [('1514',
#     'Amadora (Hospital) | Circular, via Brandoa')],
#   '132': [('1515', 'Amadora Este (Metro) - Casal de Cambra'),
#    ('1720', 'Casal de Cambra - Lisboa (C. Militar), via Amadora')],
#   '134': [('1517', 'Casal de Cambra - Reboleira (Metro)')],
#   '105': [('1518', 'Monte Abraão - Reboleira (Metro)')],
#   '157': [('1519', 'Queluz (Palácio) - Serra da Silveira')],
#   '12': [('1522', 'Algés (Terminal) - Monte Abraão (Estação)')],
#   '23': [('1524',
#     'Casal do Cotão | Circular, via Tercena, São Marcos e Taguspark')],
#   '117': [('1525', 'Caxias - Monte Abraão (Estação)'),
#    ('1526', 'Caxias (Est. Prisional) - Monte Abraão (Estação)')],
#   '102': [('1527', 'Cruz Quebrada (Estação) - Queluz (Estação)')],
#   '171': [('1528', 'Miraflores (Esc. Secundária) - Queluz (Estação)')],
#   '122': [('1529', 'Oeiras (Estação) - Bairros dos Navegadores')],
#   '106': [('1530', 'Oeiras (Estação) - Queluz'),
#    ('1601', 'Amadora Este (Metro) - Carcavelos (Praia)'),
#    ('1602', 'Carcavelos (Praia) - Queluz')],
#   '119': [('1531', 'Paço de Arcos (Estação) - São Marcos'),
#    ('1617', 'Paço de Arcos (Estação) - Talaíde (Igreja)')],
#   '133': [('1603', 'Amadora (Estação Norte) - Caneças')],
#   '463': [('1613', 'Cacém (Estação) - Oeiras (Estação), via Trajouce'),
#    ('1618', 'Abóboda (Auto Barão) - Cacém (Estação)'),
#    ('1622', 'Cacém (Estação) - Carcavelos (Estação), via Trajouce')],
#   '467': [('1614', 'Carcavelos (Estação) - Portela de Sintra (Estação)'),
#    ('1619', 'Abóboda (Auto Barão) - Portela de Sintra (Estação)')],
#   '468': [('1615', 'Carcavelos (Estação) - Rio de Mouro (Estação)'),
#    ('1620', 'Abóboda (Auto Barão) - Rio de Mouro (Estação)')],
#   '125': [('1616', 'Paço de Arcos (Estação) - Taguspark')],
#   '418': [('1621', 'Bairro da Cruz Vermelha - Portela de Sintra (Estação)'),
#    ('1629', 'Estoril (Estação) - Portela de Sintra (Estação)'),
#    ('1630',
#     'Estoril (Estação) - Portela de Sintra (Estação), via Monte Estoril e Amoreira')],
#   '417': [('1623', 'Cascais (Terminal) - Portela de Sintra (Estação)')],
#   '403': [('1624',
#     'Cascais (Terminal) - Portela de Sintra (Estação), via Azóia e Almoçageme')],
#   '455': [('1625', 'Cascais (Terminal) - Rio de Mouro (Estação)')],
#   '417/418': [('1626', 'CascaiShopping - Portela de Sintra (Estação)')],
#   '456': [('1627', 'CascaiShopping - Rio de Mouro (Estação)'),
#    ('1628', 'Estoril (Estação) -  Rio de Mouro (Estação)'),
#    ('1631', 'Estoril (Estação) - Rio de Mouro (Estação) | Direta')],
#   '202': [('1633', 'Ericeira (Terminal) - Portela de Sintra (Estação)')],
#   '124': [('1634', 'Fonte da Aranha - Montelavar')],
#   '221': [('1635', 'Almargem do Bispo (Centro de Saúde) - Caneças')],
#   '220': [('1636', 'Bairro Arco Maria Teresa - Dona Maria'),
#    ('1637', 'Casal de Cambra - Vale de Lobos'),
#    ('2626', 'Mafra (Parque Desportivo) - Portela de Sintra (Estação)')],
#   '210/231': [('1709', 'Caneças - Lisboa (C. Militar)')],
#   '210': [('1710', 'Caneças - Pontinha (Metro)')],
#   '224': [('1711', 'Caneças (Esc. Secundária) - Pontinha (Metro)')],
#   '149': [('1715', 'Belém (Estação) - Mira Sintra (Mercado)')],
#   '107': [('1716', 'Idanha - Lisboa (M. Pombal)')],
#   '101': [('1717', 'Lisboa (C. Militar) - Tercena, via Amadora Este (Metro)')],
#   '144': [('1718', 'Cacém (Bairro Grajal) - Belém (Estação)')],
#   '15': [('1732', 'Lisboa (M. Pombal) - São Marcos, via Carnaxide'),
#    ('1733', 'Lisboa (M. Pombal) - São Marcos, via Linda-a-Pastora')],
#   '215': [('2605', 'Cacém (Estação) - Loures (Lg Marcos Romão Reis Júnior)'),
#    ('2606', 'Cacém (Estação) - Caneças (Casa da Cultura)')],
#   '813/822': [('2620',
#     'Covas de Ferro - Loures (Centro Saúde), via A-Dos-Calvos')],
#   '816': [('2621', 'Covas de Ferro - Pinheiro de Loures')],
#   '239': [('2627', 'Mafra (Parque Desportivo) - Ribeira dos Tostões')],
#   '5': [('2630', 'Caneças (Esc. Secundária) | Circular')],
#   '230': [('2631', 'Casal de Cambra (C. Saúde) - Odivelas (Metro)'),
#    ('2632',
#     'Casal de Cambra (C. Saúde) - Odivelas (Metro), via Bairro Sol Nascente')],
#   '931': [('2702', 'Lisboa (C. Grande) - Pontinha (Metro)')],
#   '813/818': [('2785', 'Covas de Ferro - Lisboa (C. Grande)')],
#   '203': [('2830', 'Casal Bispo - Lisboa (C. Militar)'),
#    ('2831', 'Casal Bispo - Pontinha (Metro)')],
#   '236': [('2832', 'Casal Novo - Lisboa (C. Militar), via Casal de Cambra'),
#    ('2833', 'Pontinha (Metro) | Circular, via Casal Novo')]},
#  'Loures': {'819': [('2001', 'A-Dos-Cãos - Loures (Campo de Jogos)')],
#   '818': [('2002', 'A-dos-Cãos - Loures (Centro Saúde)')],
#   '814/817': [('2003', 'À-dos-Moninhos - Guerreiros')],
#   '826': [('2004', 'Bairro de Santa Maria - Loures (Centro Saúde)')],
#   '305': [('2005', 'Bairro do Espinhal - Sacavém (Estação)'),
#    ('2025', 'Loures (Lg Marcos Romão Reis Júnior) - Sacavém (Estação)'),
#    ('2704', 'Bairro Espinhal - Lisboa (Oriente)'),
#    ('2727', 'Lisboa (Oriente) - Loures, via Unhos')],
#   '358': [('2006', 'Bemposta - Bucelas | Circular')],
#   '342': [('2007', 'Bucelas - Mato da Cruz'),
#    ('2530', 'Alverca (Estação) - Bucelas, via Malvarosa')],
#   '357': [('2008', 'Bucelas - Romão Charneca | Circular')],
#   '211': [('2009', 'Cabeço de Montachique - Loures (Centro Saúde)'),
#    ('2011', 'Cabeço de Montachique - Loures (Centro Saúde), via Murteira')],
#   '220': [('2010',
#     'Cabeço de Montachique - Loures (Centro Saúde), via Bairro Novo Palhais')],
#   '416': [('2012', 'Conventinho - Sto. Ant. Cavaleiros'),
#    ('2020', 'Sto. Ant. Cavaleiros | Circular, via Hospital Beatriz Ângelo')],
#   '431': [('2013', 'Conventinho - Torres da Bela Vista')],
#   '417': [('2014', 'Escola Maria Veleda - Frielas')],
#   '430': [('2015', 'Flamenga - Torres da Bela Vista')],
#   '824': [('2016', 'Guerreiros - Hospital Beatriz Ângelo')],
#   '811': [('2017', 'Guerreiros - Loures (Campo de Jogos)')],
#   '427': [('2018', 'Hospital Beatriz Ângelo - Torres da Bela Vista')],
#   '426': [('2019',
#     'Hospital Beatriz Ângelo - Torres da Bela Vista, via Escola José Cardoso Pires')],
#   '337/338': [('2021', 'Infantado - Santo Antão do Tojal')],
#   '337': [('2022', 'Loures - Monte Esperança'),
#    ('2525', 'Santo Antão do Tojal - Sr. Roubado (Metro)'),
#    ('2778', 'Lisboa (C. Grande) - Santo Antão do Tojal')],
#   '301': [('2023', 'Loures (C.C. Continente) - Sacavém (Clínica Sto António)'),
#    ('2024', 'Loures (EDP) - Sacavém (Clínica Sto António)'),
#    ('2725', 'Lisboa (Oriente) - Loures (C.C. Continente)')],
#   'Nova': [('2026', 'Loures | Circular'),
#    ('2032', 'Sacavém (Estação) - Santa Iria da Azóia (Estação)'),
#    ('2033', 'Bobadela - São João da Talha | Circular'),
#    ('2034', 'Santa Iria da Azóia | Circular'),
#    ('2505', 'Loures (C. Comercial) - Malveira'),
#    ('2506', 'Milharado (CASO) - Ponte de Lousa'),
#    ('2511', 'Bairro dos CTT - Loures (C. Comercial)'),
#    ('2512', 'Bucelas - Sr. Roubado (Metro), via Ramada'),
#    ('2534', 'Loures - Santa Iria da Azóia'),
#    ('2535', 'Loures - Vila Franca de Xira'),
#    ('2539',
#     'Sacavém (Estação) - Santa Iria da Azóia (Estação), via Portela da Azóia'),
#    ('2540', 'Santa Iria da Azóia - Vialonga'),
#    ('2709', 'Camarate | Circular'),
#    ('2719', 'Lisboa (C. Grande) - Loures'),
#    ('2724', 'Lisboa (Oriente) - Loures'),
#    ('2726', 'Lisboa (Oriente) - Loures, via Sacavém'),
#    ('2733', 'Loures - Moscavide (Metro)'),
#    ('2734', 'Prior Velho - Sacavém (Estação)')],
#   '440': [('2027', 'Loures | Circular, via Cidade Nova')],
#   '441': [('2028', 'Loures | Circular, via Ponte Frielas')],
#   '303': [('2029', 'Moscavide (Metro) | Circular, via Portela')],
#   '711': [('2030', 'Sacavém (C. Saúde) - Fetais | Circular')],
#   '710': [('2031', 'Sacavém (C. Saúde) | Circular')],
#   '363': [('2035', 'Santo Antão do Tojal | Circular')],
#   '306': [('2036', 'Urbana de Camarate | Circular')],
#   '332': [('2037', 'Zambujal | Circular')],
#   '210': [('2501', 'Bocal - Malveira')],
#   '340': [('2502', 'Bucelas - Malveira')],
#   '335': [('2503', 'Bucelas - Santo Antão do Tojal'),
#    ('2510', 'Bucelas - Sr. Roubado (Metro)'),
#    ('2514', 'Casainhos - Sr. Roubado (Metro), via Loures (C.Comercial)'),
#    ('2750',
#     'Bucelas - Lisboa (C. Grande), via Cabeço de Montachique e Odivelas (Metro)'),
#    ('2766', 'Casainhos - Lisboa (C. Grande)'),
#    ('2779',
#     'Lisboa (C. Grande) - Santo Antão do Tojal, via Infantado e Loures (C.Comercial)')],
#   '207': [('2504', 'Carrascal - Ponte de Lousa')],
#   '215': [('2513',
#     'Caneças (Esc. Secundária) - Loures (Lg Marcos Romão Reis Júnior)'),
#    ('2605', 'Cacém (Estação) - Loures (Lg Marcos Romão Reis Júnior)'),
#    ('2901', 'Rolia - Venda do Pinheiro (Terminal)')],
#   '214': [('2515', 'Casal Paradela - Odivelas (Metro)'),
#    ('2768', 'Casal Paradela - Lisboa (C. Grande)')],
#   '235': [('2516', 'Casal Paradela - Sr. Roubado (Metro)')],
#   '925': [('2517', 'Hospital Beatriz Ângelo - Odivelas (Metro) | Circular')],
#   '238': [('2518', 'IKEA Loures - Sr. Roubado (Metro)')],
#   '206': [('2519',
#     'Loures (C.C. Continente) - Odivelas (Colinas do Cruzeiro)'),
#    ('2521', 'Loures (Campo de Jogos) - Odivelas (Metro)'),
#    ('2601', 'Loures (C.C. Continente) - Reboleira (Metro)'),
#    ('2746', 'Lisboa (C. Grande) - Venda do Pinheiro, via Milharado e A8'),
#    ('2780', 'Loures (C.C. Continente) - Pontinha (Metro)')],
#   '365': [('2520', 'Loures (C.Comercial) - Sr. Roubado (Metro)')],
#   '202': [('2522', 'Montemor - Sr. Roubado (Metro)')],
#   '934': [('2523', 'Odivelas (Metro) - Montemor')],
#   '225': [('2524',
#     'Odivelas (Metro) | Circular, via Hospital Beatriz Ângelo')],
#   '346': [('2531', 'Alverca (Estação) - Granja, via Casal das Areias'),
#    ('2533', 'Alverca (Estação) - Santo Antão do Tojal, via Casal das Areias')],
#   '360': [('2532', 'Alverca (Estação) - Loures')],
#   '325': [('2536', 'Póvoa de Santa Iria - Salvação | Circular')],
#   '348/370': [('2537',
#     'Póvoa de Santa Iria (Estação) - Santo Antão do Tojal')],
#   '370': [('2538',
#     'Póvoa de Santa Iria (Estação) - Santo Antão do Tojal, via Zambujal')],
#   '813/822': [('2620',
#     'Covas de Ferro - Loures (Centro Saúde), via A-Dos-Calvos')],
#   '816': [('2621', 'Covas de Ferro - Pinheiro de Loures')],
#   '470': [('2650', 'Cidade Nova - Costa da Caparica')],
#   '355': [('2651', 'Bucelas - Costa da Caparica (Terminal)')],
#   '701': [('2652', 'Costa da Caparica (Terminal) - Forte da Casa')],
#   '315': [('2703', 'Bairro de São José - Lisboa (C. Grande) | Circular')],
#   '750': [('2705', 'Bairro Espinhal - Lisboa (Oriente) | Circular')],
#   '344': [('2706', 'Bucelas - Lisboa (C. Grande)'),
#    ('2707', 'Bucelas - Lisboa (C. Grande), via São Julião do Tojal e A8')],
#   '309': [('2708', 'Cabeço Aguieira - Lisboa (Oriente)')],
#   '311': [('2710', 'Catujal (Bairro Alto Moínho) - Lisboa (C. Grande)')],
#   '310': [('2711', 'Charneca - Lisboa (Oriente)'),
#    ('2712', 'Charneca do Lumiar - Sacavém (Jardim), via Bairro de Santiago')],
#   '312/313': [('2713',
#     'Lisboa (C. Grande) | Circular, via Sacavém e Apelação')],
#   '300': [('2714', 'Lisboa (C. Grande) - Sacavém (Jardim)')],
#   '410': [('2715', 'Cidade Nova - Lisboa (C. Grande), via A8')],
#   '411': [('2716', 'Cidade Nova - Lisboa (C. Grande), via IC22')],
#   '421': [('2717', 'Lisboa (C. Grande) - Torres da Bela Vista, via IC22')],
#   '334': [('2718', 'Infantado - Lisboa (C. Grande)')],
#   '460': [('2720', 'Lisboa (C. Grande) - Loures (Bairro Urmeira)')],
#   '329': [('2721', 'Lisboa (C. Grande) - Periscoxe'),
#    ('2795', 'Lisboa (C. Grande) - Quinta da Piedade')],
#   '321': [('2722', 'Lisboa (C. Grande) - Via Rara')],
#   '333': [('2723', 'Lisboa (C. Grande) - Zambujal')],
#   '317': [('2728', 'Bairro Covina - Lisboa (Oriente)')],
#   '318': [('2729', 'Lisboa (Oriente) - Portela da Azóia')],
#   '316': [('2730', 'Lisboa (Oriente) - Santa Iria da Azóia')],
#   '308': [('2731', 'Lisboa (Oriente) - Sacavém | Circular, via Portela')],
#   '302': [('2732',
#     'Lisboa (Pç José Queirós) | Circular, via Sacavém e Camarate')],
#   '307': [('2735', 'Urbana de Sacavém | Circular, via Prior Velho')],
#   '200/208': [('2740', 'Ericeira (Terminal) - Lisboa (C. Grande), via A8'),
#    ('2741',
#     'Ericeira (Terminal) - Lisboa (C. Grande), via Ericeira (Centro), Freixeira e A8')],
#   '208': [('2742', 'Lisboa (C. Grande) - Mafra (Terminal)'),
#    ('2751', 'Ericeira (Terminal) - Lisboa (C. Grande)')],
#   '234': [('2743', 'Lisboa (C. Grande) - Póvoa da Galega, via A8 - Loures')],
#   '223': [('2744',
#     'Lisboa (C. Grande) - Póvoa da Galega, via Milharado e A8')],
#   '233': [('2745', 'Lisboa (C. Grande) - Póvoa da Galega, via Murteira')],
#   '702': [('2752', 'Lisboa (C. Grande) - Malveira')],
#   '209': [('2753', 'Lisboa (C. Grande) - Milharado')],
#   '201/237': [('2754', 'Lisboa (C. Grande) - Póvoa da Galega')],
#   '219': [('2755',
#     'Lisboa (C. Grande) - Póvoa da Galega, via Casais do Forno')],
#   '221/237/239': [('2756',
#     'Lisboa (C. Grande) - Póvoa da Galega, via Guerreiros e Lumiar')],
#   '204': [('2757',
#     'Lisboa (C. Grande) - Póvoa da Galega, via Milharado e EN8')],
#   '208/229': [('2758', 'Mafra - Lisboa (C. Grande)')],
#   '814/815': [('2760', 'À-dos-Moninhos - Lisboa (C. Grande)')],
#   '814': [('2761', 'À-dos-Moninhos - Lisboa (C. Grande), via Bolores')],
#   '336': [('2762', 'Bucelas - Lisboa (C. Grande), via A8'),
#    ('2763', 'Bucelas - Lisboa (C. Grande), via Lumiar')],
#   '331': [('2764', 'Bucelas - Lisboa (C. Grande), via S. Julão do Tojal')],
#   '202/220': [('2765', 'Cabeço de Montachique - Lisboa (C. Grande)')],
#   '331/335/336': [('2767', 'Casainhos - Lisboa (C. Grande), via Lumiar')],
#   '412': [('2769', 'Cidade Nova - Lisboa (C. Grande)')],
#   '413': [('2770', 'Cidade Nova - Lisboa (C. Grande), via Lumiar')],
#   '414/415': [('2771', 'Cidade Nova - Lisboa (C. Grande), via Urb. Flores')],
#   '422/424/426': [('2772', 'Lisboa (C. Grande) - Torres da Bela Vista')],
#   '423/425/427': [('2773',
#     'Lisboa (C. Grande) - Torres da Bela Vista, via Lumiar')],
#   '450': [('2774', 'Frielas - Lisboa (C. Grande)')],
#   '451': [('2775', 'Frielas - Lisboa (C. Grande), via Zona Industrial')],
#   '810/811': [('2776', 'Guerreiros - Lisboa (C. Grande)')],
#   '812': [('2777', 'Guerreiros - Lisboa (C. Grande), via Lumiar')],
#   '228': [('2781', 'Loures (C.C. Continente) - Pontinha (Metro), via Ramada')],
#   '813/818': [('2785', 'Covas de Ferro - Lisboa (C. Grande)')],
#   '320': [('2790', 'Alverca (Estação) - Lisboa (C. Grande)'),
#    ('2793', 'Forte da Casa - Lisboa (C. Grande)')],
#   '319': [('2791', 'Alverca (Z. Industrial) - Lisboa (C. Grande)')],
#   '347': [('2792', 'Arcena - Lisboa (Oriente)')],
#   '330': [('2794', 'Forte da Casa - Lisboa (Oriente)')],
#   '354': [('2796', 'Lisboa (C. Grande) - Vialonga')],
#   '353': [('2797', 'Lisboa (C. Grande) - Vialonga, via A8'),
#    ('2798', 'Lisboa (C. Grande) - Vialonga, via A9 e A8')]},
#  'Amadora': {'Nova': [('1001',
#     'Alfragide (Estrada do Seminario) - Reboleira (Estação)'),
#    ('1002', 'Alfragide (Igreja da Divina Misericórdia) - Amadora'),
#    ('1008', 'Amadora Este | Circular'),
#    ('1009', 'Amadora Hospital | Circular'),
#    ('1010', 'Brandoa (Esc. Secundária) - Casal da Mira'),
#    ('1012', 'Brandoa | Circular'),
#    ('1013', 'Casas do Lago - Damaia (Escola Doutor Azevedo Neves)'),
#    ('1014', 'Casas do Lago - Vila Chã'),
#    ('1015', 'Reboleira | Circular'),
#    ('1501', 'Alfragide - Reboleira (Estação) | Circular'),
#    ('1506', 'Amadora Hospital | Circular, via Alfragide'),
#    ('1509', 'Amadora (Hospital) - Casal de Cambra (C. Saúde)'),
#    ('1516', 'Casal de Cambra - Monte Abraão (Estação)'),
#    ('1719', 'Casal de Cambra - Lisboa (C. Militar)'),
#    ('2610', 'Odivelas (Metro) - UBBO'),
#    ('2611', 'UBBO - Ramada')],
#   '26 (Adaptado)': [('1003',
#     'Amadora (Estação Norte) - Amadora Este (Metro)')],
#   '118/136 (Adaptado)': [('1004',
#     'Amadora (Estação Norte) - Moinhos da Funcheira | noturna')],
#   '137 (Adaptado)': [('1005', 'Amadora (Estação Norte) - UBBO')],
#   '118 (Adaptado)': [('1006', 'Amadora (Estação Norte) - UBBO | noturna')],
#   '143': [('1007', 'Amadora (Estação Norte) | Circular madrugada'),
#    ('1703', 'Amadora (Estação Norte) - Pontinha (Metro)')],
#   '168 (Adaptado)': [('1011', 'Brandoa (Largo) - Reboleira (Metro)')],
#   '114': [('1502',
#     'Algés (Terminal) - Amadora (Estação Sul), via Linda-a-Velha')],
#   '10': [('1503', 'Algés (Terminal) - Bairro Zambujal'),
#    ('1505', 'Algés (Terminal) - IKEA Alfragide')],
#   '1': [('1504', 'Algés (Terminal) - Bairro Zambujal, via Linda-a-Velha')],
#   '108': [('1507', 'Caxias - Reboleira (Metro)')],
#   '104': [('1508', 'Almargem do Bispo - Amadora Este (Metro)')],
#   '186 (Adaptado)': [('1510',
#     'Amadora (Hospital) - Damaia (Praceta Liberdade)')],
#   '149/Nova': [('1511', 'Amadora (Hospital) - Monte Abraão (Estação)')],
#   '103': [('1512', 'Amadora (Hospital) - Montelavar')],
#   '25': [('1513', 'Amadora (Hospital) | Circular')],
#   '154/155 (Adaptado)': [('1514',
#     'Amadora (Hospital) | Circular, via Brandoa')],
#   '132': [('1515', 'Amadora Este (Metro) - Casal de Cambra'),
#    ('1720', 'Casal de Cambra - Lisboa (C. Militar), via Amadora')],
#   '134': [('1517', 'Casal de Cambra - Reboleira (Metro)')],
#   '105': [('1518', 'Monte Abraão - Reboleira (Metro)')],
#   '157': [('1519', 'Queluz (Palácio) - Serra da Silveira')],
#   '106': [('1601', 'Amadora Este (Metro) - Carcavelos (Praia)'),
#    ('1602', 'Carcavelos (Praia) - Queluz')],
#   '133': [('1603', 'Amadora (Estação Norte) - Caneças')],
#   '128': [('1701', 'Alto Brandoa - Benfica | madrugada'),
#    ('1702', 'Alto Brandoa - Lisboa (C. Militar) | madrugada'),
#    ('1706', 'Lisboa (C. Militar) - UBBO')],
#   '185': [('1704', 'Amadora (Hospital) - Lisboa (M. Pombal)')],
#   '142': [('1705',
#     'Benfica (Grão Vasco) - UBBO, via Amadora Este (Metro) | noturna e madrugada'),
#    ('1707', 'Lisboa (C. Militar) - UBBO, via Falagueira')],
#   '165': [('1708', 'UBBO | Circular')],
#   '210/231': [('1709', 'Caneças - Lisboa (C. Militar)')],
#   '210': [('1710', 'Caneças - Pontinha (Metro)')],
#   '224': [('1711', 'Caneças (Esc. Secundária) - Pontinha (Metro)')],
#   '20': [('1712', 'Algés (Terminal) - Amadora (Estação Sul)')],
#   '162': [('1713', 'Algés (Terminal) - Amadora Este (Metro)')],
#   '113': [('1714', 'Amadora (Estação Sul) - Belém (Estação)')],
#   '149': [('1715', 'Belém (Estação) - Mira Sintra (Mercado)')],
#   '107': [('1716', 'Idanha - Lisboa (M. Pombal)')],
#   '101': [('1717', 'Lisboa (C. Militar) - Tercena, via Amadora Este (Metro)')],
#   '144': [('1718', 'Cacém (Bairro Grajal) - Belém (Estação)')],
#   '163': [('1721',
#     'Lisboa (C. Militar) - Massamá (Casal do Olival), via Amadora Este (Metro)')],
#   '206': [('2601', 'Loures (C.C. Continente) - Reboleira (Metro)')],
#   '215': [('2605', 'Cacém (Estação) - Loures (Lg Marcos Romão Reis Júnior)'),
#    ('2606', 'Cacém (Estação) - Caneças (Casa da Cultura)')],
#   '227': [('2701', 'Pontinha (Metro) - Vale Grande')],
#   '931': [('2702', 'Lisboa (C. Grande) - Pontinha (Metro)')]},
#  'Alentejo Central': {'709': [('4901', 'Landeira - Setúbal (ITS)')],
#   '8902': [('4902', 'Landeira - Pegões'),
#    ('4906', 'Setúbal (ITS) - Vendas Novas, via Landeira')],
#   '8080': [('4905', 'Pegões - Vendas Novas')]},
#  'Moita': {'245': [('3650', 'Moita - Sesimbra (Terminal)')],
#   '336 (Adaptado)': [('4101',
#     'Alhos Vedros (Escola José Afonso) - Arroteias')],
#   '312 (Adaptado)': [('4102', 'Cabeço Verde - Sarilhos Pequenos')],
#   '318': [('4103', 'Moita (Estação) - Sarilhos Pequenos')],
#   '406 (Adaptado)': [('4104', 'Moita | Circular')],
#   '451': [('4530', 'Bairro Vila Morena - Pinhal Novo')],
#   '326 (Adaptado)': [('4531', 'Moita - Palmela (Terminal)')],
#   '313 (Adaptado)': [('4532', 'Moita - Quatro Marcos')],
#   '410': [('4600', 'Alcochete (Freeport) - Barreiro (Terminal)'),
#    ('4601', 'Barreiro (Terminal) - Montijo (Terminal Rodoviário)'),
#    ('4603', 'Barreiro (Terminal) - Chão Duro')],
#   '317': [('4602', 'Alhos Vedros (Estação) - Barreiro (Terminal)')],
#   '307 (Adaptado)': [('4604',
#     'Barreiro (Terminal) - Moita (Escola Fragata do Tejo)')],
#   '330': [('4605', 'Lavradio - Pinhal do Forno')],
# ...
#   '757': [('4453', 'Mitrena (Portucel) - Setúbal (ITS), via Estrada Graça')],
#   '727': [('4470', 'Brejos Azeitão - Praia do Creiro')],
#   '726': [('4471', 'Praia Albarquel | Circular')],
#   '723': [('4472', 'Praia do Creiro - Setúbal (ITS)'),
#    ('4476', 'Praias Arrábida | Circular')],
#   '725': [('4474', 'Figueirinha - Setúbal (Alegro)')],
#   '413': [('4512',
#     'Alcochete (Freeport) - Setúbal (ITS), via Alto Estanqueiro'),
#    ('4517', 'Montijo (Terminal Rodoviário) - Setúbal (ITS)')],
#   '764/765': [('4540', 'Águas de Moura - Setúbal (ITS)'),
#    ('4544', 'Bairro Margaça - Setúbal (ITS)')],
#   '779': [('4542', 'Algeruz - Setúbal (ITS)'),
#    ('4543', 'Algeruz - Setúbal (ITS), via Poçoilos')],
#   '708': [('4545', 'Biscainho - Setúbal (Bela Vista)')],
#   '774': [('4546', 'Biscainho - Setúbal (ITS)')],
#   '767': [('4547', 'Cabanas - Setúbal (ITS)'),
#    ('4549', 'Palmela (Terminal) - Setúbal (ITS)')],
#   '758': [('4548', 'Lagameças - Setúbal (ITS)')],
#   '768': [('4550', 'Palmela (Terminal) - Vila Nogueira de Azeitão')],
#   '257': [('4560', 'Cabanas - Vila Nogueira de Azeitão'),
#    ('4561', 'Cabanas - Vila Nogueira de Azeitão, via Quinta do Picão')],
#   '767/768': [('4562',
#     'Setúbal (ITS) - Vila Nogueira de Azeitão, via Palmela (Estação)')],
#   '755': [('4630', 'Corroios (Estação) - Setúbal (ITS)')],
#   '754': [('4631', 'Fogueteiro (Estação) - Setúbal (ITS)')],
#   '259': [('4640', 'Casais da Serra - Vila Nogueira de Azeitão')],
#   '770': [('4641', 'Quinta do Conde - Setúbal (ITS)')],
#   '230': [('4642', 'Sesimbra (Terminal) - Setúbal (Hospital)')],
#   '440': [('4643', 'Montijo (Av. Inf. D. Henrique) - Sesimbra (Terminal)')],
#   '563': [('4715', 'Lisboa (Oriente) - Setúbal (ITS), via Pinhal Novo')],
#   '562': [('4720', 'Lisboa (Oriente) - Setúbal (ITS)')],
#   '561': [('4725', 'Lisboa (Sete Rios) - Setúbal (Av. 5 Outubro)')],
#   '709': [('4901', 'Landeira - Setúbal (ITS)')],
#   '8902': [('4906', 'Setúbal (ITS) - Vendas Novas, via Landeira')]},
#  'Odivelas': {'133': [('1603', 'Amadora (Estação Norte) - Caneças')],
#   '221': [('1635', 'Almargem do Bispo (Centro de Saúde) - Caneças')],
#   '220': [('1636', 'Bairro Arco Maria Teresa - Dona Maria'),
#    ('1637', 'Casal de Cambra - Vale de Lobos')],
#   '210/231': [('1709', 'Caneças - Lisboa (C. Militar)')],
#   '210': [('1710', 'Caneças - Pontinha (Metro)')],
#   '224': [('1711', 'Caneças (Esc. Secundária) - Pontinha (Metro)')],
#   '926': [('2201', 'Arroja - Odivelas (Metro)')],
#   '226': [('2202', 'Arroja - Sr. Roubado (Metro)'),
#    ('2810', 'Arroja - Lisboa (C. Grande)')],
#   '208/209': [('2203', 'Arroja | Circular, via Odivelas (Metro)')],
#   'Nova': [('2204', 'Caneças - Famões'),
#    ('2210', 'Jardim da Amoreira - Odivelas'),
#    ('2222', 'Ramada | Circular'),
#    ('2511', 'Bairro dos CTT - Loures (C. Comercial)'),
#    ('2512', 'Bucelas - Sr. Roubado (Metro), via Ramada'),
#    ('2610', 'Odivelas (Metro) - UBBO'),
#    ('2611', 'UBBO - Ramada')],
#   '913': [('2205', 'Caneças (Esc. Secundária) - Odivelas (Metro)')],
#   '213': [('2206', 'Caneças (Esc. Secundária) - Sr. Roubado (Metro)')],
#   '201/901': [('2207',
#     'Caneças (Esc. Secundária) - Sr. Roubado (Metro), via Odivelas (Centro)'),
#    ('2812',
#     'Caneças (Esc. Secundária) - Lisboa (C. Grande), via Sr. Roubado (Metro)')],
#   '212': [('2208', 'Caneças (Jardim) - Vale Nogueira')],
#   '4': [('2209', 'Casal Bispo - Sr. Roubado (Metro)')],
#   '925': [('2211', 'Jardim da Amoreira - Odivelas (Metro)'),
#    ('2517', 'Hospital Beatriz Ângelo - Odivelas (Metro) | Circular')],
#   '237': [('2212', 'Odivelas (C. Comercial) | Circular')],
#   '916': [('2213', 'Odivelas (Metro) - Famões | Circular')],
#   '235': [('2214', 'Odivelas (Metro) - Póvoa de Santo Adrião (Parque Urbano)'),
#    ('2221', 'Póvoa de Santo Adrião (Parque Urbano) - Sr. Roubado (Metro)'),
#    ('2516', 'Casal Paradela - Sr. Roubado (Metro)')],
#   '211/934': [('2215', 'Odivelas (Metro) - Ramada (Bairro Bons Dias)')],
#   '225': [('2216', 'Odivelas (Metro) - Ramada (R. Heliodoro Salgado)'),
#    ('2524', 'Odivelas (Metro) | Circular, via Hospital Beatriz Ângelo')],
#   '1/3': [('2217', 'Odivelas (Metro) | Circular')],
#   '229': [('2218', 'Odivelas (Metro) | Circular, via Colinas do Cruzeiro')],
#   '207': [('2219', 'Odivelas (Metro) | Circular, via Póvoa de Santo Adrião')],
#   '240': [('2220',
#     'Olival Basto | Circular, via Póvoa de Santo Adrião e Odivelas (Metro)')],
#   '216': [('2223', 'Sr. Roubado (Metro) | Circular, via Casal Novo')],
#   '335': [('2510', 'Bucelas - Sr. Roubado (Metro)'),
#    ('2514', 'Casainhos - Sr. Roubado (Metro), via Loures (C.Comercial)'),
#    ('2750',
#     'Bucelas - Lisboa (C. Grande), via Cabeço de Montachique e Odivelas (Metro)'),
#    ('2766', 'Casainhos - Lisboa (C. Grande)'),
#    ('2779',
#     'Lisboa (C. Grande) - Santo Antão do Tojal, via Infantado e Loures (C.Comercial)')],
#   '215': [('2513',
#     'Caneças (Esc. Secundária) - Loures (Lg Marcos Romão Reis Júnior)'),
#    ('2605', 'Cacém (Estação) - Loures (Lg Marcos Romão Reis Júnior)'),
#    ('2606', 'Cacém (Estação) - Caneças (Casa da Cultura)')],
#   '214': [('2515', 'Casal Paradela - Odivelas (Metro)'),
#    ('2768', 'Casal Paradela - Lisboa (C. Grande)')],
#   '238': [('2518', 'IKEA Loures - Sr. Roubado (Metro)')],
#   '206': [('2519',
#     'Loures (C.C. Continente) - Odivelas (Colinas do Cruzeiro)'),
#    ('2521', 'Loures (Campo de Jogos) - Odivelas (Metro)'),
#    ('2601', 'Loures (C.C. Continente) - Reboleira (Metro)'),
#    ('2780', 'Loures (C.C. Continente) - Pontinha (Metro)'),
#    ('2820', 'Odivelas (Colinas do Cruzeiro) - Pontinha (Metro)'),
#    ('2821', 'Odivelas (Metro) - Pontinha (Metro)')],
#   '365': [('2520', 'Loures (C.Comercial) - Sr. Roubado (Metro)')],
#   '202': [('2522', 'Montemor - Sr. Roubado (Metro)')],
#   '934': [('2523', 'Odivelas (Metro) - Montemor')],
#   '337': [('2525', 'Santo Antão do Tojal - Sr. Roubado (Metro)'),
#    ('2778', 'Lisboa (C. Grande) - Santo Antão do Tojal')],
#   '5': [('2630', 'Caneças (Esc. Secundária) | Circular')],
#   '230': [('2631', 'Casal de Cambra (C. Saúde) - Odivelas (Metro)'),
#    ('2632',
#     'Casal de Cambra (C. Saúde) - Odivelas (Metro), via Bairro Sol Nascente')],
#   '470': [('2650', 'Cidade Nova - Costa da Caparica')],
#   '227': [('2701', 'Pontinha (Metro) - Vale Grande')],
#   '931': [('2702', 'Lisboa (C. Grande) - Pontinha (Metro)')],
#   '208': [('2751', 'Ericeira (Terminal) - Lisboa (C. Grande)')],
#   '702': [('2752', 'Lisboa (C. Grande) - Malveira')],
#   '209': [('2753', 'Lisboa (C. Grande) - Milharado')],
#   '201/237': [('2754', 'Lisboa (C. Grande) - Póvoa da Galega')],
#   '219': [('2755',
#     'Lisboa (C. Grande) - Póvoa da Galega, via Casais do Forno')],
#   '221/237/239': [('2756',
#     'Lisboa (C. Grande) - Póvoa da Galega, via Guerreiros e Lumiar')],
#   '204': [('2757',
#     'Lisboa (C. Grande) - Póvoa da Galega, via Milharado e EN8')],
#   '208/229': [('2758', 'Mafra - Lisboa (C. Grande)')],
#   '814/815': [('2760', 'À-dos-Moninhos - Lisboa (C. Grande)')],
#   '814': [('2761', 'À-dos-Moninhos - Lisboa (C. Grande), via Bolores')],
#   '336': [('2762', 'Bucelas - Lisboa (C. Grande), via A8'),
#    ('2763', 'Bucelas - Lisboa (C. Grande), via Lumiar')],
#   '331': [('2764', 'Bucelas - Lisboa (C. Grande), via S. Julão do Tojal')],
#   '202/220': [('2765', 'Cabeço de Montachique - Lisboa (C. Grande)')],
#   '331/335/336': [('2767', 'Casainhos - Lisboa (C. Grande), via Lumiar')],
#   '412': [('2769', 'Cidade Nova - Lisboa (C. Grande)')],
#   '413': [('2770', 'Cidade Nova - Lisboa (C. Grande), via Lumiar')],
#   '414/415': [('2771', 'Cidade Nova - Lisboa (C. Grande), via Urb. Flores')],
#   '422/424/426': [('2772', 'Lisboa (C. Grande) - Torres da Bela Vista')],
#   '423/425/427': [('2773',
#     'Lisboa (C. Grande) - Torres da Bela Vista, via Lumiar')],
#   '450': [('2774', 'Frielas - Lisboa (C. Grande)')],
#   '451': [('2775', 'Frielas - Lisboa (C. Grande), via Zona Industrial')],
#   '810/811': [('2776', 'Guerreiros - Lisboa (C. Grande)')],
#   '812': [('2777', 'Guerreiros - Lisboa (C. Grande), via Lumiar')],
#   '228': [('2781', 'Loures (C.C. Continente) - Pontinha (Metro), via Ramada'),
#    ('2815', 'Jardim da Amoreira - Pontinha (Metro)'),
#    ('2818', 'Lisboa (C. Militar) - Serra da Amoreira')],
#   '813/818': [('2785', 'Covas de Ferro - Lisboa (C. Grande)')],
#   '222': [('2811', 'Caneças (Bairro do Monte Verde) - Lisboa (C. Militar)'),
#    ('2823', 'Pedernais (Bairro Girassol) - Pontinha (Metro)')],
#   '223': [('2813', 'Casal Novo - Lisboa (C. Militar)'),
#    ('2814', 'Casal Novo - Pontinha (Metro)')],
#   '211': [('2816', 'Lisboa (C. Grande) - Ramada (Bairro Bons Dias)')],
#   '905': [('2817', 'Lisboa (C. Militar) - Odivelas (Metro)'),
#    ('2822', 'Odivelas (Metro) - Pontinha (Metro), via Serra da Luz')],
#   '205': [('2819', 'Lisboa (C. Militar) - Sr. Roubado (Metro)'),
#    ('2824', 'Pontinha (Metro) - Sr. Roubado (Metro)')],
#   '203': [('2830', 'Casal Bispo - Lisboa (C. Militar)'),
#    ('2831', 'Casal Bispo - Pontinha (Metro)')],
#   '236': [('2832', 'Casal Novo - Lisboa (C. Militar), via Casal de Cambra'),
#    ('2833', 'Pontinha (Metro) | Circular, via Casal Novo')],
#   '233': [('2850',
#     'Costa da Caparica - Póvoa de Santo Adrião (Parque Urbano)')]},
#  'Almada': {'470': [('2650', 'Cidade Nova - Costa da Caparica')],
#   '355': [('2651', 'Bucelas - Costa da Caparica (Terminal)')],
#   '701': [('2652', 'Costa da Caparica (Terminal) - Forte da Casa')],
#   '233': [('2850',
#     'Costa da Caparica - Póvoa de Santo Adrião (Parque Urbano)')],
#   '101': [('3001', 'Almada (Cristo Rei) - Cacilhas (Terminal)')],
#   '102': [('3003', 'Almada Forum - Cacilhas (Terminal)')],
#   'Nova': [('3026', 'Cova da Piedade - Hospital Garcia de Orta'),
#    ('3002', 'Almada (Parque Urbano) - Pragal (Estação)'),
#    ('3025', 'Costa da Caparica (Terminal) - Pragal (Estação), via IC20'),
#    ('3021', 'Costa da Caparica - Monte da Caparica (FCT)'),
#    ('3035', 'Pragal (Estação) - Quinta do Texugo'),
#    ('3017', 'Charneca da Caparica - Pragal (Estação)'),
#    ('3019', 'Charneca da Caparica - Trafaria (Terminal)'),
#    ('3016', 'Charneca da Caparica - Lazarim'),
#    ('3031', 'Monte da Caparica - Quintinha'),
#    ('3009', 'Cacilhas (terminal - Trafaria (Terminal)'),
#    ('3004', 'Almada Forum - Marisol'),
#    ('3036', 'Pragal (Estação) - Vale Flores'),
#    ('3020', 'Charneca da Caparica | Circular'),
#    ('3029', 'Marco Cabaço | Circular'),
#    ('3028', 'Lazarim | Circular'),
#    ('3033', 'Monte da Caparica | Circular'),
#    ('3006', 'Aroeira | Circular'),
#    ('3037', 'Quintinha | Circular'),
#    ('3525', 'Hospital Garcia de Orta - Miratejo'),
#    ('3505', 'Cacilhas (Terminal) - Corroios (Estação)'),
#    ('3503', 'Almada Forum - Vale de Milhaços'),
#    ('3601', 'Barreiro - Cova da Piedade (Metro)'),
#    ('3705', 'Charneca da Caparica - Lisboa (Sete Rios)'),
#    ('3701', 'Almada (Centro Sul) - Algés (Terminal)'),
#    ('3708', 'Costa da Caparica (Terminal) - Lisboa (C. Sodré)'),
#    ('3706', 'Charneca da Caparica - Lisboa (Sete Rios), via Feijó')],
#   '106': [('3007', 'Bairro Fundo Fomento - Cacilhas (Terminal)')],
#   '180': [('3018', 'Charneca da Caparica - Sobreda')],
#   '1P': [('3027', 'Hospital Garcia de Orta - Sobreda')],
#   'Flexibus': [('3005', 'Flexibus Almada | Circular')],
#   '130 (Adaptado)': [('3030', 'Fonte da Telha - Monte da Caparica (FCT)')],
#   '146 (Adaptado)': [('3034', 'Porto Brandão (Terminal) - Quinta do Texugo'),
#    ('3032', 'Monte da Caparica (FCT) - Quinta do Texugo')],
#   '124 (Adaptado)': [('3022',
#     'Costa da Caparica (Terminal) - Hospital Garcia de Orta')],
#   '174 (Adaptado)': [('3024',
#     'Costa da Caparica (Terminal) - Pragal (Estação)')],
#   '123 (Adaptado)': [('3013', 'Cacilhas (Terminal) - Monte da Caparica')],
#   '127 (Adaptado)': [('3012', 'Cacilhas (Terminal) - Fonte da Telha')],
#   '145 (Adaptado)': [('3010', 'Cacilhas (Terminal) - Charneca da Caparica')],
#   '171': [('3015', 'Charneca da Caparica - Cova do Vapor')],
#   '146': [('3008', 'Banática - Quintinha')],
#   '117': [('3014', 'Cacilhas (terminal) - Raposeira')],
#   '135': [('3011', 'Cacilhas (Terminal) - Costa da Caparica')],
#   '167': [('3023', 'Costa da Caparica (terminal) - Laranjeiro')],
#   '110': [('3513', 'Cacilhas (Terminal) - Santa Marta do Pinhal')],
#   '114': [('3508', 'Cacilhas (Terminal) - Paio Pires (Centro)')],
#   '116': [('3521', 'Cruz de Pau - Fonta da Telha'),
#    ('3523',
#     'Fonte da Telha - Paio Pires (Quinta Flamância), via Seixal (Terminal Fluvial) e Foros de Amora (Estação)')],
#   '120': [('3515', 'Caparica (Pilotos) -  Corroios')],
#   '121': [('3526', 'Laranjeiro - Pinheirinho')],
#   '139': [('3519', 'Costa da Caparica (Terminal) - Corroios (Estação)')],
#   '143': [('3518', 'Corroios (Estação) - Vale de Figueira')],
#   '149': [('3512', 'Cacilhas (Terminal) - Quinta Princesa')],
#   '159': [('3501', 'Almada Forum - Marisol, via Sobreda'),
#    ('3716', 'Lisboa (Sete Rios) - Marisol'),
#    ('3707', 'Charneca da Caparica - Lisboa (Sete Rios), via Sobreda')],
#   '163': [('3520', 'Costa da Caparica (Terminal) - Quinta do Brasileiro')],
#   '172': [('3522', 'Fonte da Telha - Paio Pires (Centro)')],
#   '191': [('3514', 'Cacilhas (Terminal) - Vale de Milhaços')],
#   '192': [('3511', 'Cacilhas (Terminal) - Pinheirinho')],
#   '196': [('3510', 'Cacilhas (Terminal) - Pilotos')],
#   '198': [('3502', 'Almada Forum - Paio Pires (Centro)'),
#    ('3527', 'Monte da Caparica (FCT) - Paio Pires (Bairro Cucena)'),
#    ('3528', 'Monte da Caparica (FCT) - Paio Pires (Centro)')],
#   '199': [('3509',
#     'Cacilhas (Terminal) - Paio Pires (Centro), via Seixal (Terminal Fluvial) e Amora')],
#   '203': [('3536', 'Cacilhas (Terminal) - Sesimbra (Terminal)')],
#   '254': [('3535', 'Cacilhas (Terminal) - Quinta do Conde')],
#   '1C': [('3516', 'Charneca da Caparica - Corroios (Estação)')],
#   '3C': [('3517', 'Chegadinho - Corroios (Estação)')],
#   '126 (Adaptado)': [('3507', 'Cacilhas (Terminal) - Marisol'),
#    ('3524', 'Hospital Garcia de Orta - Marisol')],
#   '2C (Adaptado)': [('3506',
#     'Cacilhas (Terminal) - Corroios (Estação), via Miratejo')],
#   '197': [('3504', 'Bairro Fundo Fomento - Quintinha')],
#   '583': [('3610', 'Cacilhas (Terminal) - Setúbal (ITS), via A2')],
#   '783': [('3605', 'Cacilhas (Terminal) - Setúbal (ITS), via Azeitão')],
#   '151': [('3704', 'Charneca da Caparica - Lisboa (M. Pombal)')],
#   '155': [('3709', 'Costa da Caparica (Terminal) - Lisboa (M. Pombal)')],
#   '158': [('3711', 'Monte da Caparica (FCT) - Lisboa (Sete Rios)')],
#   '160': [('3703', 'Almada (Parque Urbano) - Lisboa (Sete Rios)')],
#   '161': [('3710', 'Costa da Caparica (Terminal) - Lisboa (Sete Rios)')],
#   '162': [('3717', 'Lisboa (Sete Rios) - Quinta do Brasileiro')],
#   '169': [('3715', 'Lisboa (M. Pombal) - Santa Marta do Pinhal')],
#   '176': [('3702', 'Almada (Parque Urbano) - Lisboa (C. Universitária)')],
#   '207': [('3721', 'Lisboa (Sete Rios) - Sesimbra (Terminal)')],
#   '252': [('3720', 'Lisboa (Sete Rios) - Quinta do Conde')],
#   '561': [('4725', 'Lisboa (Sete Rios) - Setúbal (Av. 5 Outubro)')]},
#  'Barreiro': {'Nova': [('3615', 'Barreiro - Seixal'),
#    ('3625', 'Barreiro - Sesimbra (Terminal)'),
#    ('3601', 'Barreiro - Cova da Piedade (Metro)'),
#    ('4612', 'Bairro dos Marinheiros - Palmela (Terminal)'),
#    ('4621', 'Moita - Seixal (Terminal Fluvial)')],
#   '245': [('3650', 'Moita - Sesimbra (Terminal)')],
#   '2N': [('3626', 'Coina (Estação) - Vila Fresca de Azeitão')],
#   '783': [('3605', 'Cacilhas (Terminal) - Setúbal (ITS), via Azeitão')],
#   '1N': [('3620', 'Coina (Estação) - Quinta do Conde')],
#   '410': [('4600', 'Alcochete (Freeport) - Barreiro (Terminal)'),
#    ('4601', 'Barreiro (Terminal) - Montijo (Terminal Rodoviário)'),
#    ('4603', 'Barreiro (Terminal) - Chão Duro')],
#   '317': [('4602', 'Alhos Vedros (Estação) - Barreiro (Terminal)')],
#   '307 (Adaptado)': [('4604',
#     'Barreiro (Terminal) - Moita (Escola Fragata do Tejo)')],
#   '330': [('4605', 'Lavradio - Pinhal do Forno')],
#   '305': [('4610', 'Bairro dos Marinheiros - Barreiro (Terminal)')],
#   '311 (Adaptado)': [('4611', 'Penalva - Moita (Esc. Secundária)')],
#   '302': [('4620', 'Moita - Paio Pires')],
#   '755': [('4630', 'Corroios (Estação) - Setúbal (ITS)')],
#   '754': [('4631', 'Fogueteiro (Estação) - Setúbal (ITS)')]}}

# %%
diretorio['Oeiras']['158']
# Out:
# [('1113', 'Caxias (Estação) - Lage'),
#  ('1114', 'Caxias (Estação) - Paço de Arcos (Estação)'),
#  ('1115', 'Caxias (Pedreira Italiana) - Lage'),
#  ('1116', 'Caxias (Pedreira Italiana) - Paço de Arcos (Estação)'),
#  ('1117', 'Caxias (Quinta da Moura) - Lage'),
#  ('1118', 'Caxias (Quinta da Moura) - Paço de Arcos (Estação)')]

# %% [markdown]
# # Criar HTML
#
# ```html
#     <div>
#         Territorio:
#         <select id="territorio" name="territorio">
#             <option value="nada">-</option>
#             <option value="carris">Carris</option>
#             <option value="vimeca">Vimeca</option>
#         </select>
#     </div>
# ```

# %%
html = ''

html = """    <div>
        Territorio:
        <select id="territorio" name="territorio">
            <option value="nada">-</option>\n"""

for territorio in sorted(diretorio.keys()):
    html += f'            <option value="{territorio}">{territorio}</option>\n'

html += """        </select>
    </div>\n\n"""


print(html)
# Out:
#     <div>
#         Territorio:
#         <select id="territorio" name="territorio">
#             <option value="nada">-</option>
#             <option value="Alcochete">Alcochete</option>
#             <option value="Alentejo Central">Alentejo Central</option>
#             <option value="Almada">Almada</option>
#             <option value="Amadora">Amadora</option>
#             <option value="Barreiro">Barreiro</option>
#             <option value="Cascais">Cascais</option>
#             <option value="Lisboa">Lisboa</option>
#             <option value="Loures">Loures</option>
#             <option value="Mafra">Mafra</option>
#             <option value="Moita">Moita</option>
#             <option value="Montijo">Montijo</option>
#             <option value="Odivelas">Odivelas</option>
#             <option value="Oeiras">Oeiras</option>
#             <option value="Oeste">Oeste</option>
#             <option value="Palmela">Palmela</option>
#             <option value="Seixal">Seixal</option>
#             <option value="Sesimbra">Sesimbra</option>
#             <option value="Setúbal">Setúbal</option>
#             <option value="Sintra">Sintra</option>
#             <option value="Vila Franca de Xira">Vila Franca de Xira</option>
#         </select>
#     </div>

# %%
html = ''

html = """    <div class="municipios">
        Municípios:
        <select id="territorio" name="territorio">
            <option value="nada">-</option>\n"""

for territorio in sorted(diretorio.keys()):
    html += f'            <option value="{territorio}">{territorio}</option>\n'

html += """        </select>
    </div>\n\n<div class="antigas">\n"""


for territorio,carreiras in sorted(diretorio.items()):
    html += f'    <div class="carreira-div" id="{territorio}-div">\n'
    html += f'        Linha antiga:\n'
    html += f'        <select class="carreira" id="{territorio}" onchange="mostraNova(' + f"'{territorio}'" +')">\n'
    html += f'            <option value="nada">-</option>\n'
    
    for antiga, novas  in sorted(carreiras.items()):
        
        if antiga != "Nova":
            h = "<ul>"
            for item in novas:
                h += f"<li><b>{item[0]}</b>:{item[1]}</li>"
            h += "</ul>"        

            html += f'            <option value="{h}">{antiga}</option>\n' 

    html += """         </select>
    </div>\n\n"""
    
    
html += "  </div>"

# %%
html = ''

html = """    <div class="municipios">
        Municípios:
        <select id="territorio" name="territorio">
            <option value="nada">-</option>\n"""

for territorio in sorted(diretorio.keys()):
    html += f'            <option value="{territorio}">{territorio}</option>\n'

html += """        </select>
    </div>\n\n<div class="antigas">\n"""


for territorio,carreiras in sorted(diretorio.items()):
    html += f'    <div class="carreira-div" id="{territorio}-div">\n'
    html += f'        Linha antiga:\n'
    html += f'        <select class="carreira" id="{territorio}" onchange="mostraNova(' + f"'{territorio}'" +')">\n'
    html += f'            <option value="nada">-</option>\n'
    
    novas_linhas = []
    for antiga, novas  in sorted(carreiras.items()):
        
        if antiga == "Nova":
            novas_linhas += [novas]
        else:
            h = "<ul>"
            for item in novas:
                h += f"<li><b>{item[0]}</b>:{item[1]}</li>"
            h += "</ul>"        

            html += f'            <option value="{h}">{antiga}</option>\n' 

    html += """         </select>
    
    
     """
    
    h = "<ul>"
    for linha in novas_linhas:
        for l in linha:
            h += f"<li><b>{l[0]}</b>: {l[1]}</li>"
    h += "</ul>"  
        
    
    html += f"<br><br><details><summary>Linhas novas</summary><div>{h}</div></details>" 
    
    
    
    
    html += """
    
    </div>\n\n"""

    
html += "  </div>"

# %%
print(html)
# Out:
#     <div class="municipios">
#         Municípios:
#         <select id="territorio" name="territorio">
#             <option value="nada">-</option>
#             <option value="Alcochete">Alcochete</option>
#             <option value="Alentejo Central">Alentejo Central</option>
#             <option value="Almada">Almada</option>
#             <option value="Amadora">Amadora</option>
#             <option value="Barreiro">Barreiro</option>
#             <option value="Cascais">Cascais</option>
#             <option value="Lisboa">Lisboa</option>
#             <option value="Loures">Loures</option>
#             <option value="Mafra">Mafra</option>
#             <option value="Moita">Moita</option>
#             <option value="Montijo">Montijo</option>
#             <option value="Odivelas">Odivelas</option>
#             <option value="Oeiras">Oeiras</option>
#             <option value="Oeste">Oeste</option>
#             <option value="Palmela">Palmela</option>
#             <option value="Seixal">Seixal</option>
#             <option value="Sesimbra">Sesimbra</option>
#             <option value="Setúbal">Setúbal</option>
#             <option value="Sintra">Sintra</option>
#             <option value="Vila Franca de Xira">Vila Franca de Xira</option>
#         </select>
#     </div>
#
# <div class="antigas">
#     <div class="carreira-div" id="Alcochete-div">
#         Linha antiga:
#         <select class="carreira" id="Alcochete" onchange="mostraNova('Alcochete')">
#             <option value="nada">-</option>
#             <option value="<ul><li><b>4511</b>:Alcochete (Freeport) - Montijo (Terminal Rodoviário), via Samouco</li><li><b>4600</b>:Alcochete (Freeport) - Barreiro (Terminal)</li></ul>">410</option>
#             <option value="<ul><li><b>4510</b>:Alcochete (Freeport) - Montijo (Terminal Rodoviário)</li><li><b>4512</b>:Alcochete (Freeport) - Setúbal (ITS), via Alto Estanqueiro</li><li><b>4513</b>:Alcochete (Freeport) - Pinhal Novo</li></ul>">413</option>
#             <option value="<ul><li><b>4514</b>:Canha - Montijo (Terminal Rodoviário), via Pegões</li></ul>">414/416</option>
#             <option value="<ul><li><b>4504</b>:Montijo (Terminal Fluvial) - Passil</li></ul>">415</option>
#             <option value="<ul><li><b>4515</b>:Montijo (Terminal Rodoviário) - Pegões</li></ul>">416</option>
#             <option value="<ul><li><b>4502</b>:Alcochete - Passil</li></ul>">419</option>
#             <option value="<ul><li><b>4516</b>:Montijo (Terminal Rodoviário) - Rio Frio</li></ul>">426</option>
#             <option value="<ul><li><b>4703</b>:Lisboa (Oriente) - Montijo (Terminal Rodoviário), via Alcochete e Samouco</li></ul>">431</option>
#             <option value="<ul><li><b>4702</b>:Lisboa (Oriente) - Valbom</li><li><b>4704</b>:Atalaia - Lisboa (Oriente)</li></ul>">432</option>
#             <option value="<ul><li><b>4705</b>:Lisboa (Oriente) - Samouco</li></ul>">435</option>
#             <option value="<ul><li><b>4706</b>:São Francisco - Lisboa (Oriente)</li></ul>">453</option>
#          </select>
#
#
#      <br><br><details><summary>Linhas novas</summary><div><ul><li><b>4001</b>: Alcochete | Circular</li><li><b>4002</b>: São Francisco | Circular</li><li><b>4501</b>: Alcochete - Montijo (Terminal Fluvial)</li><li><b>4503</b>: Atalaia - Jardia</li></ul></div></details>
#
#     </div>
#
#     <div class="carreira-div" id="Alentejo Central-div">
#         Linha antiga:
#         <select class="carreira" id="Alentejo Central" onchange="mostraNova('Alentejo Central')">
#             <option value="nada">-</option>
#             <option value="<ul><li><b>4901</b>:Landeira - Setúbal (ITS)</li></ul>">709</option>
#             <option value="<ul><li><b>4905</b>:Pegões - Vendas Novas</li></ul>">8080</option>
#             <option value="<ul><li><b>4902</b>:Landeira - Pegões</li><li><b>4906</b>:Setúbal (ITS) - Vendas Novas, via Landeira</li></ul>">8902</option>
#          </select>
#
#
#      <br><br><details><summary>Linhas novas</summary><div><ul></ul></div></details>
#
#     </div>
#
#     <div class="carreira-div" id="Almada-div">
#         Linha antiga:
#         <select class="carreira" id="Almada" onchange="mostraNova('Almada')">
#             <option value="nada">-</option>
#             <option value="<ul><li><b>3001</b>:Almada (Cristo Rei) - Cacilhas (Terminal)</li></ul>">101</option>
#             <option value="<ul><li><b>3003</b>:Almada Forum - Cacilhas (Terminal)</li></ul>">102</option>
#             <option value="<ul><li><b>3007</b>:Bairro Fundo Fomento - Cacilhas (Terminal)</li></ul>">106</option>
#             <option value="<ul><li><b>3513</b>:Cacilhas (Terminal) - Santa Marta do Pinhal</li></ul>">110</option>
#             <option value="<ul><li><b>3508</b>:Cacilhas (Terminal) - Paio Pires (Centro)</li></ul>">114</option>
#             <option value="<ul><li><b>3521</b>:Cruz de Pau - Fonta da Telha</li><li><b>3523</b>:Fonte da Telha - Paio Pires (Quinta Flamância), via Seixal (Terminal Fluvial) e Foros de Amora (Estação)</li></ul>">116</option>
#             <option value="<ul><li><b>3014</b>:Cacilhas (terminal) - Raposeira</li></ul>">117</option>
#             <option value="<ul><li><b>3515</b>:Caparica (Pilotos) -  Corroios</li></ul>">120</option>
#             <option value="<ul><li><b>3526</b>:Laranjeiro - Pinheirinho</li></ul>">121</option>
#             <option value="<ul><li><b>3013</b>:Cacilhas (Terminal) - Monte da Caparica</li></ul>">123 (Adaptado)</option>
#             <option value="<ul><li><b>3022</b>:Costa da Caparica (Terminal) - Hospital Garcia de Orta</li></ul>">124 (Adaptado)</option>
#             <option value="<ul><li><b>3507</b>:Cacilhas (Terminal) - Marisol</li><li><b>3524</b>:Hospital Garcia de Orta - Marisol</li></ul>">126 (Adaptado)</option>
#             <option value="<ul><li><b>3012</b>:Cacilhas (Terminal) - Fonte da Telha</li></ul>">127 (Adaptado)</option>
#             <option value="<ul><li><b>3030</b>:Fonte da Telha - Monte da Caparica (FCT)</li></ul>">130 (Adaptado)</option>
#             <option value="<ul><li><b>3011</b>:Cacilhas (Terminal) - Costa da Caparica</li></ul>">135</option>
#             <option value="<ul><li><b>3519</b>:Costa da Caparica (Terminal) - Corroios (Estação)</li></ul>">139</option>
#             <option value="<ul><li><b>3518</b>:Corroios (Estação) - Vale de Figueira</li></ul>">143</option>
#             <option value="<ul><li><b>3010</b>:Cacilhas (Terminal) - Charneca da Caparica</li></ul>">145 (Adaptado)</option>
#             <option value="<ul><li><b>3008</b>:Banática - Quintinha</li></ul>">146</option>
#             <option value="<ul><li><b>3034</b>:Porto Brandão (Terminal) - Quinta do Texugo</li><li><b>3032</b>:Monte da Caparica (FCT) - Quinta do Texugo</li></ul>">146 (Adaptado)</option>
#             <option value="<ul><li><b>3512</b>:Cacilhas (Terminal) - Quinta Princesa</li></ul>">149</option>
#             <option value="<ul><li><b>3704</b>:Charneca da Caparica - Lisboa (M. Pombal)</li></ul>">151</option>
#             <option value="<ul><li><b>3709</b>:Costa da Caparica (Terminal) - Lisboa (M. Pombal)</li></ul>">155</option>
#             <option value="<ul><li><b>3711</b>:Monte da Caparica (FCT) - Lisboa (Sete Rios)</li></ul>">158</option>
#             <option value="<ul><li><b>3501</b>:Almada Forum - Marisol, via Sobreda</li><li><b>3716</b>:Lisboa (Sete Rios) - Marisol</li><li><b>3707</b>:Charneca da Caparica - Lisboa (Sete Rios), via Sobreda</li></ul>">159</option>
#             <option value="<ul><li><b>3703</b>:Almada (Parque Urbano) - Lisboa (Sete Rios)</li></ul>">160</option>
#             <option value="<ul><li><b>3710</b>:Costa da Caparica (Terminal) - Lisboa (Sete Rios)</li></ul>">161</option>
#             <option value="<ul><li><b>3717</b>:Lisboa (Sete Rios) - Quinta do Brasileiro</li></ul>">162</option>
#             <option value="<ul><li><b>3520</b>:Costa da Caparica (Terminal) - Quinta do Brasileiro</li></ul>">163</option>
#             <option value="<ul><li><b>3023</b>:Costa da Caparica (terminal) - Laranjeiro</li></ul>">167</option>
#             <option value="<ul><li><b>3715</b>:Lisboa (M. Pombal) - Santa Marta do Pinhal</li></ul>">169</option>
#             <option value="<ul><li><b>3015</b>:Charneca da Caparica - Cova do Vapor</li></ul>">171</option>
#             <option value="<ul><li><b>3522</b>:Fonte da Telha - Paio Pires (Centro)</li></ul>">172</option>
#             <option value="<ul><li><b>3024</b>:Costa da Caparica (Terminal) - Pragal (Estação)</li></ul>">174 (Adaptado)</option>
#             <option value="<ul><li><b>3702</b>:Almada (Parque Urbano) - Lisboa (C. Universitária)</li></ul>">176</option>
#             <option value="<ul><li><b>3018</b>:Charneca da Caparica - Sobreda</li></ul>">180</option>
#             <option value="<ul><li><b>3514</b>:Cacilhas (Terminal) - Vale de Milhaços</li></ul>">191</option>
#             <option value="<ul><li><b>3511</b>:Cacilhas (Terminal) - Pinheirinho</li></ul>">192</option>
#             <option value="<ul><li><b>3510</b>:Cacilhas (Terminal) - Pilotos</li></ul>">196</option>
#             <option value="<ul><li><b>3504</b>:Bairro Fundo Fomento - Quintinha</li></ul>">197</option>
#             <option value="<ul><li><b>3502</b>:Almada Forum - Paio Pires (Centro)</li><li><b>3527</b>:Monte da Caparica (FCT) - Paio Pires (Bairro Cucena)</li><li><b>3528</b>:Monte da Caparica (FCT) - Paio Pires (Centro)</li></ul>">198</option>
#             <option value="<ul><li><b>3509</b>:Cacilhas (Terminal) - Paio Pires (Centro), via Seixal (Terminal Fluvial) e Amora</li></ul>">199</option>
#             <option value="<ul><li><b>3516</b>:Charneca da Caparica - Corroios (Estação)</li></ul>">1C</option>
#             <option value="<ul><li><b>3027</b>:Hospital Garcia de Orta - Sobreda</li></ul>">1P</option>
#             <option value="<ul><li><b>3536</b>:Cacilhas (Terminal) - Sesimbra (Terminal)</li></ul>">203</option>
#             <option value="<ul><li><b>3721</b>:Lisboa (Sete Rios) - Sesimbra (Terminal)</li></ul>">207</option>
#             <option value="<ul><li><b>2850</b>:Costa da Caparica - Póvoa de Santo Adrião (Parque Urbano)</li></ul>">233</option>
#             <option value="<ul><li><b>3720</b>:Lisboa (Sete Rios) - Quinta do Conde</li></ul>">252</option>
#             <option value="<ul><li><b>3535</b>:Cacilhas (Terminal) - Quinta do Conde</li></ul>">254</option>
#             <option value="<ul><li><b>3506</b>:Cacilhas (Terminal) - Corroios (Estação), via Miratejo</li></ul>">2C (Adaptado)</option>
#             <option value="<ul><li><b>2651</b>:Bucelas - Costa da Caparica (Terminal)</li></ul>">355</option>
#             <option value="<ul><li><b>3517</b>:Chegadinho - Corroios (Estação)</li></ul>">3C</option>
#             <option value="<ul><li><b>2650</b>:Cidade Nova - Costa da Caparica</li></ul>">470</option>
#             <option value="<ul><li><b>4725</b>:Lisboa (Sete Rios) - Setúbal (Av. 5 Outubro)</li></ul>">561</option>
#             <option value="<ul><li><b>3610</b>:Cacilhas (Terminal) - Setúbal (ITS), via A2</li></ul>">583</option>
#             <option value="<ul><li><b>2652</b>:Costa da Caparica (Terminal) - Forte da Casa</li></ul>">701</option>
#             <option value="<ul><li><b>3605</b>:Cacilhas (Terminal) - Setúbal (ITS), via Azeitão</li></ul>">783</option>
#             <option value="<ul><li><b>3005</b>:Flexibus Almada | Circular</li></ul>">Flexibus</option>
#          </select>
#
#
#      <br><br><details><summary>Linhas novas</summary><div><ul><li><b>3026</b>: Cova da Piedade - Hospital Garcia de Orta</li><li><b>3002</b>: Almada (Parque Urbano) - Pragal (Estação)</li><li><b>3025</b>: Costa da Caparica (Terminal) - Pragal (Estação), via IC20</li><li><b>3021</b>: Costa da Caparica - Monte da Caparica (FCT)</li><li><b>3035</b>: Pragal (Estação) - Quinta do Texugo</li><li><b>3017</b>: Charneca da Caparica - Pragal (Estação)</li><li><b>3019</b>: Charneca da Caparica - Trafaria (Terminal)</li><li><b>3016</b>: Charneca da Caparica - Lazarim</li><li><b>3031</b>: Monte da Caparica - Quintinha</li><li><b>3009</b>: Cacilhas (terminal - Trafaria (Terminal)</li><li><b>3004</b>: Almada Forum - Marisol</li><li><b>3036</b>: Pragal (Estação) - Vale Flores</li><li><b>3020</b>: Charneca da Caparica | Circular</li><li><b>3029</b>: Marco Cabaço | Circular</li><li><b>3028</b>: Lazarim | Circular</li><li><b>3033</b>: Monte da Caparica | Circular</li><li><b>3006</b>: Aroeira | Circular</li><li><b>3037</b>: Quintinha | Circular</li><li><b>3525</b>: Hospital Garcia de Orta - Miratejo</li><li><b>3505</b>: Cacilhas (Terminal) - Corroios (Estação)</li><li><b>3503</b>: Almada Forum - Vale de Milhaços</li><li><b>3601</b>: Barreiro - Cova da Piedade (Metro)</li><li><b>3705</b>: Charneca da Caparica - Lisboa (Sete Rios)</li><li><b>3701</b>: Almada (Centro Sul) - Algés (Terminal)</li><li><b>3708</b>: Costa da Caparica (Terminal) - Lisboa (C. Sodré)</li><li><b>3706</b>: Charneca da Caparica - Lisboa (Sete Rios), via Feijó</li></ul></div></details>
#
#     </div>
#
#     <div class="carreira-div" id="Amadora-div">
#         Linha antiga:
#         <select class="carreira" id="Amadora" onchange="mostraNova('Amadora')">
#             <option value="nada">-</option>
#             <option value="<ul><li><b>1504</b>:Algés (Terminal) - Bairro Zambujal, via Linda-a-Velha</li></ul>">1</option>
#             <option value="<ul><li><b>1503</b>:Algés (Terminal) - Bairro Zambujal</li><li><b>1505</b>:Algés (Terminal) - IKEA Alfragide</li></ul>">10</option>
#             <option value="<ul><li><b>1717</b>:Lisboa (C. Militar) - Tercena, via Amadora Este (Metro)</li></ul>">101</option>
#             <option value="<ul><li><b>1512</b>:Amadora (Hospital) - Montelavar</li></ul>">103</option>
#             <option value="<ul><li><b>1508</b>:Almargem do Bispo - Amadora Este (Metro)</li></ul>">104</option>
#             <option value="<ul><li><b>1518</b>:Monte Abraão - Reboleira (Metro)</li></ul>">105</option>
#             <option value="<ul><li><b>1601</b>:Amadora Este (Metro) - Carcavelos (Praia)</li><li><b>1602</b>:Carcavelos (Praia) - Queluz</li></ul>">106</option>
#             <option value="<ul><li><b>1716</b>:Idanha - Lisboa (M. Pombal)</li></ul>">107</option>
#             <option value="<ul><li><b>1507</b>:Caxias - Reboleira (Metro)</li></ul>">108</option>
#             <option value="<ul><li><b>1714</b>:Amadora (Estação Sul) - Belém (Estação)</li></ul>">113</option>
#             <option value="<ul><li><b>1502</b>:Algés (Terminal) - Amadora (Estação Sul), via Linda-a-Velha</li></ul>">114</option>
#             <option value="<ul><li><b>1006</b>:Amadora (Estação Norte) - UBBO | noturna</li></ul>">118 (Adaptado)</option>
#             <option value="<ul><li><b>1004</b>:Amadora (Estação Norte) - Moinhos da Funcheira | noturna</li></ul>">118/136 (Adaptado)</option>
#             <option value="<ul><li><b>1701</b>:Alto Brandoa - Benfica | madrugada</li><li><b>1702</b>:Alto Brandoa - Lisboa (C. Militar) | madrugada</li><li><b>1706</b>:Lisboa (C. Militar) - UBBO</li></ul>">128</option>
#             <option value="<ul><li><b>1515</b>:Amadora Este (Metro) - Casal de Cambra</li><li><b>1720</b>:Casal de Cambra - Lisboa (C. Militar), via Amadora</li></ul>">132</option>
#             <option value="<ul><li><b>1603</b>:Amadora (Estação Norte) - Caneças</li></ul>">133</option>
#             <option value="<ul><li><b>1517</b>:Casal de Cambra - Reboleira (Metro)</li></ul>">134</option>
#             <option value="<ul><li><b>1005</b>:Amadora (Estação Norte) - UBBO</li></ul>">137 (Adaptado)</option>
#             <option value="<ul><li><b>1705</b>:Benfica (Grão Vasco) - UBBO, via Amadora Este (Metro) | noturna e madrugada</li><li><b>1707</b>:Lisboa (C. Militar) - UBBO, via Falagueira</li></ul>">142</option>
#             <option value="<ul><li><b>1007</b>:Amadora (Estação Norte) | Circular madrugada</li><li><b>1703</b>:Amadora (Estação Norte) - Pontinha (Metro)</li></ul>">143</option>
#             <option value="<ul><li><b>1718</b>:Cacém (Bairro Grajal) - Belém (Estação)</li></ul>">144</option>
#             <option value="<ul><li><b>1715</b>:Belém (Estação) - Mira Sintra (Mercado)</li></ul>">149</option>
#             <option value="<ul><li><b>1511</b>:Amadora (Hospital) - Monte Abraão (Estação)</li></ul>">149/Nova</option>
#             <option value="<ul><li><b>1514</b>:Amadora (Hospital) | Circular, via Brandoa</li></ul>">154/155 (Adaptado)</option>
#             <option value="<ul><li><b>1519</b>:Queluz (Palácio) - Serra da Silveira</li></ul>">157</option>
#             <option value="<ul><li><b>1713</b>:Algés (Terminal) - Amadora Este (Metro)</li></ul>">162</option>
#             <option value="<ul><li><b>1721</b>:Lisboa (C. Militar) - Massamá (Casal do Olival), via Amadora Este (Metro)</li></ul>">163</option>
#             <option value="<ul><li><b>1708</b>:UBBO | Circular</li></ul>">165</option>
#             <option value="<ul><li><b>1011</b>:Brandoa (Largo) - Reboleira (Metro)</li></ul>">168 (Adaptado)</option>
#             <option value="<ul><li><b>1704</b>:Amadora (Hospital) - Lisboa (M. Pombal)</li></ul>">185</option>
#             <option value="<ul><li><b>1510</b>:Amadora (Hospital) - Damaia (Praceta Liberdade)</li></ul>">186 (Adaptado)</option>
#             <option value="<ul><li><b>1712</b>:Algés (Terminal) - Amadora (Estação Sul)</li></ul>">20</option>
#             <option value="<ul><li><b>2601</b>:Loures (C.C. Continente) - Reboleira (Metro)</li></ul>">206</option>
#             <option value="<ul><li><b>1710</b>:Caneças - Pontinha (Metro)</li></ul>">210</option>
#             <option value="<ul><li><b>1709</b>:Caneças - Lisboa (C. Militar)</li></ul>">210/231</option>
#             <option value="<ul><li><b>2605</b>:Cacém (Estação) - Loures (Lg Marcos Romão Reis Júnior)</li><li><b>2606</b>:Cacém (Estação) - Caneças (Casa da Cultura)</li></ul>">215</option>
#             <option value="<ul><li><b>1711</b>:Caneças (Esc. Secundária) - Pontinha (Metro)</li></ul>">224</option>
#             <option value="<ul><li><b>2701</b>:Pontinha (Metro) - Vale Grande</li></ul>">227</option>
#             <option value="<ul><li><b>1513</b>:Amadora (Hospital) | Circular</li></ul>">25</option>
#             <option value="<ul><li><b>1003</b>:Amadora (Estação Norte) - Amadora Este (Metro)</li></ul>">26 (Adaptado)</option>
#             <option value="<ul><li><b>2702</b>:Lisboa (C. Grande) - Pontinha (Metro)</li></ul>">931</option>
#          </select>
#
#
#      <br><br><details><summary>Linhas novas</summary><div><ul><li><b>1001</b>: Alfragide (Estrada do Seminario) - Reboleira (Estação)</li><li><b>1002</b>: Alfragide (Igreja da Divina Misericórdia) - Amadora</li><li><b>1008</b>: Amadora Este | Circular</li><li><b>1009</b>: Amadora Hospital | Circular</li><li><b>1010</b>: Brandoa (Esc. Secundária) - Casal da Mira</li><li><b>1012</b>: Brandoa | Circular</li><li><b>1013</b>: Casas do Lago - Damaia (Escola Doutor Azevedo Neves)</li><li><b>1014</b>: Casas do Lago - Vila Chã</li><li><b>1015</b>: Reboleira | Circular</li><li><b>1501</b>: Alfragide - Reboleira (Estação) | Circular</li><li><b>1506</b>: Amadora Hospital | Circular, via Alfragide</li><li><b>1509</b>: Amadora (Hospital) - Casal de Cambra (C. Saúde)</li><li><b>1516</b>: Casal de Cambra - Monte Abraão (Estação)</li><li><b>1719</b>: Casal de Cambra - Lisboa (C. Militar)</li><li><b>2610</b>: Odivelas (Metro) - UBBO</li><li><b>2611</b>: UBBO - Ramada</li></ul></div></details>
#
#     </div>
#
#     <div class="carreira-div" id="Barreiro-div">
#         Linha antiga:
#         <select class="carreira" id="Barreiro" onchange="mostraNova('Barreiro')">
#             <option value="nada">-</option>
#             <option value="<ul><li><b>3620</b>:Coina (Estação) - Quinta do Conde</li></ul>">1N</option>
#             <option value="<ul><li><b>3650</b>:Moita - Sesimbra (Terminal)</li></ul>">245</option>
#             <option value="<ul><li><b>3626</b>:Coina (Estação) - Vila Fresca de Azeitão</li></ul>">2N</option>
#             <option value="<ul><li><b>4620</b>:Moita - Paio Pires</li></ul>">302</option>
#             <option value="<ul><li><b>4610</b>:Bairro dos Marinheiros - Barreiro (Terminal)</li></ul>">305</option>
#             <option value="<ul><li><b>4604</b>:Barreiro (Terminal) - Moita (Escola Fragata do Tejo)</li></ul>">307 (Adaptado)</option>
#             <option value="<ul><li><b>4611</b>:Penalva - Moita (Esc. Secundária)</li></ul>">311 (Adaptado)</option>
#             <option value="<ul><li><b>4602</b>:Alhos Vedros (Estação) - Barreiro (Terminal)</li></ul>">317</option>
#             <option value="<ul><li><b>4605</b>:Lavradio - Pinhal do Forno</li></ul>">330</option>
#             <option value="<ul><li><b>4600</b>:Alcochete (Freeport) - Barreiro (Terminal)</li><li><b>4601</b>:Barreiro (Terminal) - Montijo (Terminal Rodoviário)</li><li><b>4603</b>:Barreiro (Terminal) - Chão Duro</li></ul>">410</option>
#             <option value="<ul><li><b>4631</b>:Fogueteiro (Estação) - Setúbal (ITS)</li></ul>">754</option>
#             <option value="<ul><li><b>4630</b>:Corroios (Estação) - Setúbal (ITS)</li></ul>">755</option>
#             <option value="<ul><li><b>3605</b>:Cacilhas (Terminal) - Setúbal (ITS), via Azeitão</li></ul>">783</option>
#          </select>
#
#
#      <br><br><details><summary>Linhas novas</summary><div><ul><li><b>3615</b>: Barreiro - Seixal</li><li><b>3625</b>: Barreiro - Sesimbra (Terminal)</li><li><b>3601</b>: Barreiro - Cova da Piedade (Metro)</li><li><b>4612</b>: Bairro dos Marinheiros - Palmela (Terminal)</li><li><b>4621</b>: Moita - Seixal (Terminal Fluvial)</li></ul></div></details>
#
#     </div>
#
#     <div class="carreira-div" id="Cascais-div">
#         Linha antiga:
#         <select class="carreira" id="Cascais" onchange="mostraNova('Cascais')">
#             <option value="nada">-</option>
#             <option value="<ul><li><b>1601</b>:Amadora Este (Metro) - Carcavelos (Praia)</li><li><b>1602</b>:Carcavelos (Praia) - Queluz</li></ul>">106</option>
#             <option value="<ul><li><b>1617</b>:Paço de Arcos (Estação) - Talaíde (Igreja)</li></ul>">119</option>
#             <option value="<ul><li><b>1610</b>:Paço de Arcos (Estação) - Talaíde (Campo de Futebol)</li><li><b>1616</b>:Paço de Arcos (Estação) - Taguspark</li></ul>">125</option>
#             <option value="<ul><li><b>1611</b>:Paço de Arcos (Estação) - Talaíde (Campo de Futebol), via Vila Fria</li></ul>">184</option>
#             <option value="<ul><li><b>1624</b>:Cascais (Terminal) - Portela de Sintra (Estação), via Azóia e Almoçageme</li></ul>">403</option>
#             <option value="<ul><li><b>1623</b>:Cascais (Terminal) - Portela de Sintra (Estação)</li></ul>">417</option>
#             <option value="<ul><li><b>1626</b>:CascaiShopping - Portela de Sintra (Estação)</li></ul>">417/418</option>
#             <option value="<ul><li><b>1621</b>:Bairro da Cruz Vermelha - Portela de Sintra (Estação)</li><li><b>1629</b>:Estoril (Estação) - Portela de Sintra (Estação)</li><li><b>1630</b>:Estoril (Estação) - Portela de Sintra (Estação), via Monte Estoril e Amoreira</li></ul>">418</option>
#             <option value="<ul><li><b>1625</b>:Cascais (Terminal) - Rio de Mouro (Estação)</li></ul>">455</option>
#             <option value="<ul><li><b>1627</b>:CascaiShopping - Rio de Mouro (Estação)</li><li><b>1628</b>:Estoril (Estação) -  Rio de Mouro (Estação)</li><li><b>1631</b>:Estoril (Estação) - Rio de Mouro (Estação) | Direta</li></ul>">456</option>
#             <option value="<ul><li><b>1613</b>:Cacém (Estação) - Oeiras (Estação), via Trajouce</li><li><b>1618</b>:Abóboda (Auto Barão) - Cacém (Estação)</li><li><b>1622</b>:Cacém (Estação) - Carcavelos (Estação), via Trajouce</li></ul>">463</option>
#             <option value="<ul><li><b>1614</b>:Carcavelos (Estação) - Portela de Sintra (Estação)</li><li><b>1619</b>:Abóboda (Auto Barão) - Portela de Sintra (Estação)</li></ul>">467</option>
#             <option value="<ul><li><b>1615</b>:Carcavelos (Estação) - Rio de Mouro (Estação)</li><li><b>1620</b>:Abóboda (Auto Barão) - Rio de Mouro (Estação)</li></ul>">468</option>
#             <option value="<ul><li><b>1607</b>:Conceição da Abóboda - Oeiras (Estação)</li><li><b>1608</b>:Oeiras (Estação) - Taguspark</li><li><b>1609</b>:Oeiras (Estação) - Talaíde (Igreja)</li></ul>">470</option>
#             <option value="<ul><li><b>1604</b>:Carcavelos (Estação) - Parede (Terminal)</li></ul>">471</option>
#          </select>
#
#
#      <br><br><details><summary>Linhas novas</summary><div><ul><li><b>1605</b>: Carnaxide (Av. João Paulo II) - Nova SBE</li><li><b>1606</b>: Carnaxide (Av. João Paulo II) - Nova SBE, via Terrugem</li><li><b>1612</b>: Cacém (Estação) - Carcavelos (Estação)</li></ul></div></details>
#
#     </div>
#
#     <div class="carreira-div" id="Lisboa-div">
#         Linha antiga:
#         <select class="carreira" id="Lisboa" onchange="mostraNova('Lisboa')">
#             <option value="nada">-</option>
#             <option value="<ul><li><b>1722</b>:Alfragide (Alegro) - Hospital São Francisco Xavier</li></ul>">1</option>
#             <option value="<ul><li><b>1717</b>:Lisboa (C. Militar) - Tercena, via Amadora Este (Metro)</li></ul>">101</option>
#             <option value="<ul><li><b>1716</b>:Idanha - Lisboa (M. Pombal)</li></ul>">107</option>
#             <option value="<ul><li><b>1724</b>:Linda-a-Velha - Lisboa (M. Pombal)</li></ul>">11</option>
#             <option value="<ul><li><b>1714</b>:Amadora (Estação Sul) - Belém (Estação)</li></ul>">113</option>
#             <option value="<ul><li><b>1725</b>:Lisboa (M. Pombal) - Oeiras (Estação)</li></ul>">115</option>
#             <option value="<ul><li><b>1701</b>:Alto Brandoa - Benfica | madrugada</li><li><b>1702</b>:Alto Brandoa - Lisboa (C. Militar) | madrugada</li><li><b>1706</b>:Lisboa (C. Militar) - UBBO</li></ul>">128</option>
#             <option value="<ul><li><b>1726</b>:Lisboa (M. Pombal) - Queijas</li><li><b>1728</b>:Lisboa (M. Pombal) - Queijas, via Linda-a-Velha</li><li><b>1730</b>:Lisboa (M. Pombal) - Queluz Baixo, via Linda-a-Velha</li></ul>">13</option>
#             <option value="<ul><li><b>1720</b>:Casal de Cambra - Lisboa (C. Militar), via Amadora</li></ul>">132</option>
#             <option value="<ul><li><b>1729</b>:Lisboa (M. Pombal) - Queluz Baixo (C.C.)</li></ul>">13D</option>
#             <option value="<ul><li><b>1727</b>:Lisboa (M. Pombal) - Queijas, via A5</li></ul>">13D/15</option>
#             <option value="<ul><li><b>1705</b>:Benfica (Grão Vasco) - UBBO, via Amadora Este (Metro) | noturna e madrugada</li><li><b>1707</b>:Lisboa (C. Militar) - UBBO, via Falagueira</li></ul>">142</option>
#             <option value="<ul><li><b>1703</b>:Amadora (Estação Norte) - Pontinha (Metro)</li></ul>">143</option>
#             <option value="<ul><li><b>1718</b>:Cacém (Bairro Grajal) - Belém (Estação)</li></ul>">144</option>
#             <option value="<ul><li><b>1715</b>:Belém (Estação) - Mira Sintra (Mercado)</li></ul>">149</option>
#             <option value="<ul><li><b>1732</b>:Lisboa (M. Pombal) - São Marcos, via Carnaxide</li><li><b>1733</b>:Lisboa (M. Pombal) - São Marcos, via Linda-a-Pastora</li></ul>">15</option>
#             <option value="<ul><li><b>3704</b>:Charneca da Caparica - Lisboa (M. Pombal)</li></ul>">151</option>
#             <option value="<ul><li><b>3709</b>:Costa da Caparica (Terminal) - Lisboa (M. Pombal)</li></ul>">155</option>
#             <option value="<ul><li><b>3711</b>:Monte da Caparica (FCT) - Lisboa (Sete Rios)</li></ul>">158</option>
#             <option value="<ul><li><b>3716</b>:Lisboa (Sete Rios) - Marisol</li><li><b>3707</b>:Charneca da Caparica - Lisboa (Sete Rios), via Sobreda</li></ul>">159</option>
#             <option value="<ul><li><b>3703</b>:Almada (Parque Urbano) - Lisboa (Sete Rios)</li></ul>">160</option>
#             <option value="<ul><li><b>3710</b>:Costa da Caparica (Terminal) - Lisboa (Sete Rios)</li></ul>">161</option>
#             <option value="<ul><li><b>1713</b>:Algés (Terminal) - Amadora Este (Metro)</li><li><b>3717</b>:Lisboa (Sete Rios) - Quinta do Brasileiro</li></ul>">162</option>
#             <option value="<ul><li><b>1721</b>:Lisboa (C. Militar) - Massamá (Casal do Olival), via Amadora Este (Metro)</li></ul>">163</option>
#             <option value="<ul><li><b>1708</b>:UBBO | Circular</li></ul>">165</option>
#             <option value="<ul><li><b>3715</b>:Lisboa (M. Pombal) - Santa Marta do Pinhal</li></ul>">169</option>
#             <option value="<ul><li><b>3702</b>:Almada (Parque Urbano) - Lisboa (C. Universitária)</li></ul>">176</option>
#             <option value="<ul><li><b>1704</b>:Amadora (Hospital) - Lisboa (M. Pombal)</li></ul>">185</option>
#             <option value="<ul><li><b>1712</b>:Algés (Terminal) - Amadora (Estação Sul)</li></ul>">20</option>
#             <option value="<ul><li><b>2804</b>:Mafra - Lisboa (C. Grande), via A8</li></ul>">200</option>
#             <option value="<ul><li><b>2740</b>:Ericeira (Terminal) - Lisboa (C. Grande), via A8</li><li><b>2741</b>:Ericeira (Terminal) - Lisboa (C. Grande), via Ericeira (Centro), Freixeira e A8</li></ul>">200/208</option>
#             <option value="<ul><li><b>2754</b>:Lisboa (C. Grande) - Póvoa da Galega</li></ul>">201/237</option>
#             <option value="<ul><li><b>2812</b>:Caneças (Esc. Secundária) - Lisboa (C. Grande), via Sr. Roubado (Metro)</li></ul>">201/901</option>
#             <option value="<ul><li><b>2765</b>:Cabeço de Montachique - Lisboa (C. Grande)</li></ul>">202/220</option>
#             <option value="<ul><li><b>2830</b>:Casal Bispo - Lisboa (C. Militar)</li><li><b>2831</b>:Casal Bispo - Pontinha (Metro)</li></ul>">203</option>
#             <option value="<ul><li><b>2757</b>:Lisboa (C. Grande) - Póvoa da Galega, via Milharado e EN8</li></ul>">204</option>
#             <option value="<ul><li><b>2819</b>:Lisboa (C. Militar) - Sr. Roubado (Metro)</li><li><b>2824</b>:Pontinha (Metro) - Sr. Roubado (Metro)</li></ul>">205</option>
#             <option value="<ul><li><b>2746</b>:Lisboa (C. Grande) - Venda do Pinheiro, via Milharado e A8</li><li><b>2780</b>:Loures (C.C. Continente) - Pontinha (Metro)</li><li><b>2820</b>:Odivelas (Colinas do Cruzeiro) - Pontinha (Metro)</li><li><b>2821</b>:Odivelas (Metro) - Pontinha (Metro)</li></ul>">206</option>
#             <option value="<ul><li><b>3721</b>:Lisboa (Sete Rios) - Sesimbra (Terminal)</li></ul>">207</option>
#             <option value="<ul><li><b>2801</b>:Ericeira (Terminal) - Lisboa (C. Grande), via A21/A8</li></ul>">207/246</option>
#             <option value="<ul><li><b>2742</b>:Lisboa (C. Grande) - Mafra (Terminal)</li><li><b>2751</b>:Ericeira (Terminal) - Lisboa (C. Grande)</li></ul>">208</option>
#             <option value="<ul><li><b>2758</b>:Mafra - Lisboa (C. Grande)</li></ul>">208/229</option>
#             <option value="<ul><li><b>2753</b>:Lisboa (C. Grande) - Milharado</li><li><b>2802</b>:Lisboa (C. Grande) - Mafra (Terminal), via A21</li><li><b>2803</b>:Ericeira (Terminal) - Lisboa (C. Grande), via Mafra e A21/A8</li></ul>">209</option>
#             <option value="<ul><li><b>1710</b>:Caneças - Pontinha (Metro)</li></ul>">210</option>
#             <option value="<ul><li><b>1709</b>:Caneças - Lisboa (C. Militar)</li></ul>">210/231</option>
#             <option value="<ul><li><b>2816</b>:Lisboa (C. Grande) - Ramada (Bairro Bons Dias)</li></ul>">211</option>
#             <option value="<ul><li><b>2768</b>:Casal Paradela - Lisboa (C. Grande)</li></ul>">214</option>
#             <option value="<ul><li><b>2755</b>:Lisboa (C. Grande) - Póvoa da Galega, via Casais do Forno</li></ul>">219</option>
#             <option value="<ul><li><b>2756</b>:Lisboa (C. Grande) - Póvoa da Galega, via Guerreiros e Lumiar</li></ul>">221/237/239</option>
#             <option value="<ul><li><b>2811</b>:Caneças (Bairro do Monte Verde) - Lisboa (C. Militar)</li><li><b>2823</b>:Pedernais (Bairro Girassol) - Pontinha (Metro)</li></ul>">222</option>
#             <option value="<ul><li><b>2744</b>:Lisboa (C. Grande) - Póvoa da Galega, via Milharado e A8</li><li><b>2813</b>:Casal Novo - Lisboa (C. Militar)</li><li><b>2814</b>:Casal Novo - Pontinha (Metro)</li></ul>">223</option>
#             <option value="<ul><li><b>1711</b>:Caneças (Esc. Secundária) - Pontinha (Metro)</li></ul>">224</option>
#             <option value="<ul><li><b>2805</b>:Encarnação - Lisboa (C. Grande)</li></ul>">225</option>
#             <option value="<ul><li><b>2810</b>:Arroja - Lisboa (C. Grande)</li></ul>">226</option>
#             <option value="<ul><li><b>2701</b>:Pontinha (Metro) - Vale Grande</li></ul>">227</option>
#             <option value="<ul><li><b>2781</b>:Loures (C.C. Continente) - Pontinha (Metro), via Ramada</li><li><b>2815</b>:Jardim da Amoreira - Pontinha (Metro)</li><li><b>2818</b>:Lisboa (C. Militar) - Serra da Amoreira</li></ul>">228</option>
#             <option value="<ul><li><b>2807</b>:Lisboa (C. Grande) - Zambujal, via Mafra</li></ul>">229</option>
#             <option value="<ul><li><b>2900</b>:Lisboa (C. Grande) - São Sebastião</li></ul>">230</option>
#             <option value="<ul><li><b>2745</b>:Lisboa (C. Grande) - Póvoa da Galega, via Murteira</li><li><b>2850</b>:Costa da Caparica - Póvoa de Santo Adrião (Parque Urbano)</li></ul>">233</option>
#             <option value="<ul><li><b>2743</b>:Lisboa (C. Grande) - Póvoa da Galega, via A8 - Loures</li></ul>">234</option>
#             <option value="<ul><li><b>2832</b>:Casal Novo - Lisboa (C. Militar), via Casal de Cambra</li><li><b>2833</b>:Pontinha (Metro) | Circular, via Casal Novo</li></ul>">236</option>
#             <option value="<ul><li><b>3720</b>:Lisboa (Sete Rios) - Quinta do Conde</li></ul>">252</option>
#             <option value="<ul><li><b>2714</b>:Lisboa (C. Grande) - Sacavém (Jardim)</li></ul>">300</option>
#             <option value="<ul><li><b>2725</b>:Lisboa (Oriente) - Loures (C.C. Continente)</li></ul>">301</option>
#             <option value="<ul><li><b>2732</b>:Lisboa (Pç José Queirós) | Circular, via Sacavém e Camarate</li></ul>">302</option>
#             <option value="<ul><li><b>2704</b>:Bairro Espinhal - Lisboa (Oriente)</li><li><b>2727</b>:Lisboa (Oriente) - Loures, via Unhos</li></ul>">305</option>
#             <option value="<ul><li><b>2735</b>:Urbana de Sacavém | Circular, via Prior Velho</li></ul>">307</option>
#             <option value="<ul><li><b>2731</b>:Lisboa (Oriente) - Sacavém | Circular, via Portela</li></ul>">308</option>
#             <option value="<ul><li><b>2708</b>:Cabeço Aguieira - Lisboa (Oriente)</li></ul>">309</option>
#             <option value="<ul><li><b>2711</b>:Charneca - Lisboa (Oriente)</li><li><b>2712</b>:Charneca do Lumiar - Sacavém (Jardim), via Bairro de Santiago</li></ul>">310</option>
#             <option value="<ul><li><b>2710</b>:Catujal (Bairro Alto Moínho) - Lisboa (C. Grande)</li></ul>">311</option>
#             <option value="<ul><li><b>2713</b>:Lisboa (C. Grande) | Circular, via Sacavém e Apelação</li></ul>">312/313</option>
#             <option value="<ul><li><b>2703</b>:Bairro de São José - Lisboa (C. Grande) | Circular</li></ul>">315</option>
#             <option value="<ul><li><b>2730</b>:Lisboa (Oriente) - Santa Iria da Azóia</li></ul>">316</option>
#             <option value="<ul><li><b>2728</b>:Bairro Covina - Lisboa (Oriente)</li></ul>">317</option>
#             <option value="<ul><li><b>2729</b>:Lisboa (Oriente) - Portela da Azóia</li></ul>">318</option>
#             <option value="<ul><li><b>2791</b>:Alverca (Z. Industrial) - Lisboa (C. Grande)</li></ul>">319</option>
#             <option value="<ul><li><b>2790</b>:Alverca (Estação) - Lisboa (C. Grande)</li><li><b>2793</b>:Forte da Casa - Lisboa (C. Grande)</li></ul>">320</option>
#             <option value="<ul><li><b>2722</b>:Lisboa (C. Grande) - Via Rara</li></ul>">321</option>
#             <option value="<ul><li><b>2721</b>:Lisboa (C. Grande) - Periscoxe</li><li><b>2795</b>:Lisboa (C. Grande) - Quinta da Piedade</li></ul>">329</option>
#             <option value="<ul><li><b>2794</b>:Forte da Casa - Lisboa (Oriente)</li></ul>">330</option>
#             <option value="<ul><li><b>2764</b>:Bucelas - Lisboa (C. Grande), via S. Julão do Tojal</li></ul>">331</option>
#             <option value="<ul><li><b>2767</b>:Casainhos - Lisboa (C. Grande), via Lumiar</li></ul>">331/335/336</option>
#             <option value="<ul><li><b>2723</b>:Lisboa (C. Grande) - Zambujal</li><li><b>4701</b>:Lisboa (Oriente) - Vale da Amoreira</li></ul>">333</option>
#             <option value="<ul><li><b>2718</b>:Infantado - Lisboa (C. Grande)</li></ul>">334</option>
#             <option value="<ul><li><b>2750</b>:Bucelas - Lisboa (C. Grande), via Cabeço de Montachique e Odivelas (Metro)</li><li><b>2766</b>:Casainhos - Lisboa (C. Grande)</li><li><b>2779</b>:Lisboa (C. Grande) - Santo Antão do Tojal, via Infantado e Loures (C.Comercial)</li></ul>">335</option>
#             <option value="<ul><li><b>2762</b>:Bucelas - Lisboa (C. Grande), via A8</li><li><b>2763</b>:Bucelas - Lisboa (C. Grande), via Lumiar</li></ul>">336</option>
#             <option value="<ul><li><b>2778</b>:Lisboa (C. Grande) - Santo Antão do Tojal</li></ul>">337</option>
#             <option value="<ul><li><b>2706</b>:Bucelas - Lisboa (C. Grande)</li><li><b>2707</b>:Bucelas - Lisboa (C. Grande), via São Julião do Tojal e A8</li></ul>">344</option>
#             <option value="<ul><li><b>2792</b>:Arcena - Lisboa (Oriente)</li><li><b>2840</b>:Arcena - Lisboa (Oriente), via A1</li></ul>">347</option>
#             <option value="<ul><li><b>2797</b>:Lisboa (C. Grande) - Vialonga, via A8</li><li><b>2798</b>:Lisboa (C. Grande) - Vialonga, via A9 e A8</li></ul>">353</option>
#             <option value="<ul><li><b>2796</b>:Lisboa (C. Grande) - Vialonga</li></ul>">354</option>
#             <option value="<ul><li><b>2715</b>:Cidade Nova - Lisboa (C. Grande), via A8</li></ul>">410</option>
#             <option value="<ul><li><b>2716</b>:Cidade Nova - Lisboa (C. Grande), via IC22</li></ul>">411</option>
#             <option value="<ul><li><b>2769</b>:Cidade Nova - Lisboa (C. Grande)</li></ul>">412</option>
#             <option value="<ul><li><b>2770</b>:Cidade Nova - Lisboa (C. Grande), via Lumiar</li></ul>">413</option>
#             <option value="<ul><li><b>2771</b>:Cidade Nova - Lisboa (C. Grande), via Urb. Flores</li></ul>">414/415</option>
#             <option value="<ul><li><b>2717</b>:Lisboa (C. Grande) - Torres da Bela Vista, via IC22</li></ul>">421</option>
#             <option value="<ul><li><b>2772</b>:Lisboa (C. Grande) - Torres da Bela Vista</li></ul>">422/424/426</option>
#             <option value="<ul><li><b>2773</b>:Lisboa (C. Grande) - Torres da Bela Vista, via Lumiar</li></ul>">423/425/427</option>
#             <option value="<ul><li><b>4703</b>:Lisboa (Oriente) - Montijo (Terminal Rodoviário), via Alcochete e Samouco</li></ul>">431</option>
#             <option value="<ul><li><b>4702</b>:Lisboa (Oriente) - Valbom</li><li><b>4704</b>:Atalaia - Lisboa (Oriente)</li></ul>">432</option>
#             <option value="<ul><li><b>4705</b>:Lisboa (Oriente) - Samouco</li><li><b>4707</b>:Lisboa (Oriente) - Montijo (Terminal Rodoviário)</li></ul>">435</option>
#             <option value="<ul><li><b>2774</b>:Frielas - Lisboa (C. Grande)</li></ul>">450</option>
#             <option value="<ul><li><b>2775</b>:Frielas - Lisboa (C. Grande), via Zona Industrial</li></ul>">451</option>
#             <option value="<ul><li><b>4706</b>:São Francisco - Lisboa (Oriente)</li></ul>">453</option>
#             <option value="<ul><li><b>2720</b>:Lisboa (C. Grande) - Loures (Bairro Urmeira)</li></ul>">460</option>
#             <option value="<ul><li><b>4725</b>:Lisboa (Sete Rios) - Setúbal (Av. 5 Outubro)</li></ul>">561</option>
#             <option value="<ul><li><b>4720</b>:Lisboa (Oriente) - Setúbal (ITS)</li></ul>">562</option>
#             <option value="<ul><li><b>4715</b>:Lisboa (Oriente) - Setúbal (ITS), via Pinhal Novo</li></ul>">563</option>
#             <option value="<ul><li><b>4710</b>:Lisboa (Oriente) - Palmela (Terminal)</li><li><b>4711</b>:Lisboa (Oriente) - Pinhal Novo</li></ul>">565</option>
#             <option value="<ul><li><b>1723</b>:Carnaxide - Lisboa (M. Pombal)</li></ul>">7/13</option>
#             <option value="<ul><li><b>2806</b>:Lisboa (C. Grande) - Livramento</li></ul>">701</option>
#             <option value="<ul><li><b>2752</b>:Lisboa (C. Grande) - Malveira</li></ul>">702</option>
#             <option value="<ul><li><b>2841</b>:Lisboa (C. Grande) - Sobralinho</li></ul>">72</option>
#             <option value="<ul><li><b>2705</b>:Bairro Espinhal - Lisboa (Oriente) | Circular</li></ul>">750</option>
#             <option value="<ul><li><b>2776</b>:Guerreiros - Lisboa (C. Grande)</li></ul>">810/811</option>
#             <option value="<ul><li><b>2777</b>:Guerreiros - Lisboa (C. Grande), via Lumiar</li></ul>">812</option>
#             <option value="<ul><li><b>2785</b>:Covas de Ferro - Lisboa (C. Grande)</li></ul>">813/818</option>
#             <option value="<ul><li><b>2761</b>:À-dos-Moninhos - Lisboa (C. Grande), via Bolores</li></ul>">814</option>
#             <option value="<ul><li><b>2760</b>:À-dos-Moninhos - Lisboa (C. Grande)</li></ul>">814/815</option>
#             <option value="<ul><li><b>2817</b>:Lisboa (C. Militar) - Odivelas (Metro)</li><li><b>2822</b>:Odivelas (Metro) - Pontinha (Metro), via Serra da Luz</li></ul>">905</option>
#             <option value="<ul><li><b>2702</b>:Lisboa (C. Grande) - Pontinha (Metro)</li></ul>">931</option>
#          </select>
#
#
#      <br><br><details><summary>Linhas novas</summary><div><ul><li><b>1719</b>: Casal de Cambra - Lisboa (C. Militar)</li><li><b>1731</b>: Cacém (Estação) - Hospital São Francisco Xavier</li><li><b>2709</b>: Camarate | Circular</li><li><b>2719</b>: Lisboa (C. Grande) - Loures</li><li><b>2724</b>: Lisboa (Oriente) - Loures</li><li><b>2726</b>: Lisboa (Oriente) - Loures, via Sacavém</li><li><b>2733</b>: Loures - Moscavide (Metro)</li><li><b>2734</b>: Prior Velho - Sacavém (Estação)</li><li><b>2842</b>: Lisboa (C. Grande) - Vila Franca de Xira</li><li><b>3705</b>: Charneca da Caparica - Lisboa (Sete Rios)</li><li><b>3701</b>: Almada (Centro Sul) - Algés (Terminal)</li><li><b>3708</b>: Costa da Caparica (Terminal) - Lisboa (C. Sodré)</li><li><b>3706</b>: Charneca da Caparica - Lisboa (Sete Rios), via Feijó</li></ul></div></details>
#
#     </div>
#
#     <div class="carreira-div" id="Loures-div">
#         Linha antiga:
#         <select class="carreira" id="Loures" onchange="mostraNova('Loures')">
#             <option value="nada">-</option>
#             <option value="<ul><li><b>2740</b>:Ericeira (Terminal) - Lisboa (C. Grande), via A8</li><li><b>2741</b>:Ericeira (Terminal) - Lisboa (C. Grande), via Ericeira (Centro), Freixeira e A8</li></ul>">200/208</option>
#             <option value="<ul><li><b>2754</b>:Lisboa (C. Grande) - Póvoa da Galega</li></ul>">201/237</option>
#             <option value="<ul><li><b>2522</b>:Montemor - Sr. Roubado (Metro)</li></ul>">202</option>
#             <option value="<ul><li><b>2765</b>:Cabeço de Montachique - Lisboa (C. Grande)</li></ul>">202/220</option>
#             <option value="<ul><li><b>2757</b>:Lisboa (C. Grande) - Póvoa da Galega, via Milharado e EN8</li></ul>">204</option>
#             <option value="<ul><li><b>2519</b>:Loures (C.C. Continente) - Odivelas (Colinas do Cruzeiro)</li><li><b>2521</b>:Loures (Campo de Jogos) - Odivelas (Metro)</li><li><b>2601</b>:Loures (C.C. Continente) - Reboleira (Metro)</li><li><b>2746</b>:Lisboa (C. Grande) - Venda do Pinheiro, via Milharado e A8</li><li><b>2780</b>:Loures (C.C. Continente) - Pontinha (Metro)</li></ul>">206</option>
#             <option value="<ul><li><b>2504</b>:Carrascal - Ponte de Lousa</li></ul>">207</option>
#             <option value="<ul><li><b>2742</b>:Lisboa (C. Grande) - Mafra (Terminal)</li><li><b>2751</b>:Ericeira (Terminal) - Lisboa (C. Grande)</li></ul>">208</option>
#             <option value="<ul><li><b>2758</b>:Mafra - Lisboa (C. Grande)</li></ul>">208/229</option>
#             <option value="<ul><li><b>2753</b>:Lisboa (C. Grande) - Milharado</li></ul>">209</option>
#             <option value="<ul><li><b>2501</b>:Bocal - Malveira</li></ul>">210</option>
#             <option value="<ul><li><b>2009</b>:Cabeço de Montachique - Loures (Centro Saúde)</li><li><b>2011</b>:Cabeço de Montachique - Loures (Centro Saúde), via Murteira</li></ul>">211</option>
#             <option value="<ul><li><b>2515</b>:Casal Paradela - Odivelas (Metro)</li><li><b>2768</b>:Casal Paradela - Lisboa (C. Grande)</li></ul>">214</option>
#             <option value="<ul><li><b>2513</b>:Caneças (Esc. Secundária) - Loures (Lg Marcos Romão Reis Júnior)</li><li><b>2605</b>:Cacém (Estação) - Loures (Lg Marcos Romão Reis Júnior)</li><li><b>2901</b>:Rolia - Venda do Pinheiro (Terminal)</li></ul>">215</option>
#             <option value="<ul><li><b>2755</b>:Lisboa (C. Grande) - Póvoa da Galega, via Casais do Forno</li></ul>">219</option>
#             <option value="<ul><li><b>2010</b>:Cabeço de Montachique - Loures (Centro Saúde), via Bairro Novo Palhais</li></ul>">220</option>
#             <option value="<ul><li><b>2756</b>:Lisboa (C. Grande) - Póvoa da Galega, via Guerreiros e Lumiar</li></ul>">221/237/239</option>
#             <option value="<ul><li><b>2744</b>:Lisboa (C. Grande) - Póvoa da Galega, via Milharado e A8</li></ul>">223</option>
#             <option value="<ul><li><b>2524</b>:Odivelas (Metro) | Circular, via Hospital Beatriz Ângelo</li></ul>">225</option>
#             <option value="<ul><li><b>2781</b>:Loures (C.C. Continente) - Pontinha (Metro), via Ramada</li></ul>">228</option>
#             <option value="<ul><li><b>2745</b>:Lisboa (C. Grande) - Póvoa da Galega, via Murteira</li></ul>">233</option>
#             <option value="<ul><li><b>2743</b>:Lisboa (C. Grande) - Póvoa da Galega, via A8 - Loures</li></ul>">234</option>
#             <option value="<ul><li><b>2516</b>:Casal Paradela - Sr. Roubado (Metro)</li></ul>">235</option>
#             <option value="<ul><li><b>2518</b>:IKEA Loures - Sr. Roubado (Metro)</li></ul>">238</option>
#             <option value="<ul><li><b>2714</b>:Lisboa (C. Grande) - Sacavém (Jardim)</li></ul>">300</option>
#             <option value="<ul><li><b>2023</b>:Loures (C.C. Continente) - Sacavém (Clínica Sto António)</li><li><b>2024</b>:Loures (EDP) - Sacavém (Clínica Sto António)</li><li><b>2725</b>:Lisboa (Oriente) - Loures (C.C. Continente)</li></ul>">301</option>
#             <option value="<ul><li><b>2732</b>:Lisboa (Pç José Queirós) | Circular, via Sacavém e Camarate</li></ul>">302</option>
#             <option value="<ul><li><b>2029</b>:Moscavide (Metro) | Circular, via Portela</li></ul>">303</option>
#             <option value="<ul><li><b>2005</b>:Bairro do Espinhal - Sacavém (Estação)</li><li><b>2025</b>:Loures (Lg Marcos Romão Reis Júnior) - Sacavém (Estação)</li><li><b>2704</b>:Bairro Espinhal - Lisboa (Oriente)</li><li><b>2727</b>:Lisboa (Oriente) - Loures, via Unhos</li></ul>">305</option>
#             <option value="<ul><li><b>2036</b>:Urbana de Camarate | Circular</li></ul>">306</option>
#             <option value="<ul><li><b>2735</b>:Urbana de Sacavém | Circular, via Prior Velho</li></ul>">307</option>
#             <option value="<ul><li><b>2731</b>:Lisboa (Oriente) - Sacavém | Circular, via Portela</li></ul>">308</option>
#             <option value="<ul><li><b>2708</b>:Cabeço Aguieira - Lisboa (Oriente)</li></ul>">309</option>
#             <option value="<ul><li><b>2711</b>:Charneca - Lisboa (Oriente)</li><li><b>2712</b>:Charneca do Lumiar - Sacavém (Jardim), via Bairro de Santiago</li></ul>">310</option>
#             <option value="<ul><li><b>2710</b>:Catujal (Bairro Alto Moínho) - Lisboa (C. Grande)</li></ul>">311</option>
#             <option value="<ul><li><b>2713</b>:Lisboa (C. Grande) | Circular, via Sacavém e Apelação</li></ul>">312/313</option>
#             <option value="<ul><li><b>2703</b>:Bairro de São José - Lisboa (C. Grande) | Circular</li></ul>">315</option>
#             <option value="<ul><li><b>2730</b>:Lisboa (Oriente) - Santa Iria da Azóia</li></ul>">316</option>
#             <option value="<ul><li><b>2728</b>:Bairro Covina - Lisboa (Oriente)</li></ul>">317</option>
# ...
#             <option value="<ul><li><b>1519</b>:Queluz (Palácio) - Serra da Silveira</li></ul>">157</option>
#             <option value="<ul><li><b>1209</b>:Bairro da Felosa - Mira Sintra (Mercado)</li></ul>">160</option>
#             <option value="<ul><li><b>1222</b>:Cacém (Estação) | Circular, via Bairro Joaquim Fontes</li></ul>">161</option>
#             <option value="<ul><li><b>1227</b>:Massamá (Casal do Olival) - Queluz</li><li><b>1721</b>:Lisboa (C. Militar) - Massamá (Casal do Olival), via Amadora Este (Metro)</li></ul>">163</option>
#             <option value="<ul><li><b>1224</b>:Carregueira (Estabelecimento prisional) - Monte Abraão (Estação)</li></ul>">164</option>
#             <option value="<ul><li><b>1215</b>:Cacém (Estação) - Encosta de São Marcos</li><li><b>1217</b>:Cacém (Estação) - Massamá (Urbanização Norte)</li><li><b>1225</b>:Encosta de São Marcos - Massamá (Urbanização Norte)</li></ul>">170</option>
#             <option value="<ul><li><b>1528</b>:Miraflores (Esc. Secundária) - Queluz (Estação)</li></ul>">171</option>
#             <option value="<ul><li><b>1212</b>:Cacém (Bairro Grajal) - Queluz (Estação)</li></ul>">179</option>
#             <option value="<ul><li><b>1510</b>:Amadora (Hospital) - Damaia (Praceta Liberdade)</li></ul>">186 (Adaptado)</option>
#             <option value="<ul><li><b>1633</b>:Ericeira (Terminal) - Portela de Sintra (Estação)</li></ul>">202</option>
#             <option value="<ul><li><b>2830</b>:Casal Bispo - Lisboa (C. Militar)</li><li><b>2831</b>:Casal Bispo - Pontinha (Metro)</li></ul>">203</option>
#             <option value="<ul><li><b>1710</b>:Caneças - Pontinha (Metro)</li></ul>">210</option>
#             <option value="<ul><li><b>1709</b>:Caneças - Lisboa (C. Militar)</li></ul>">210/231</option>
#             <option value="<ul><li><b>2605</b>:Cacém (Estação) - Loures (Lg Marcos Romão Reis Júnior)</li><li><b>2606</b>:Cacém (Estação) - Caneças (Casa da Cultura)</li></ul>">215</option>
#             <option value="<ul><li><b>1216</b>:Casal do Cotão | Circular, via Tercena e São Marcos</li></ul>">22</option>
#             <option value="<ul><li><b>1636</b>:Bairro Arco Maria Teresa - Dona Maria</li><li><b>1637</b>:Casal de Cambra - Vale de Lobos</li><li><b>2626</b>:Mafra (Parque Desportivo) - Portela de Sintra (Estação)</li></ul>">220</option>
#             <option value="<ul><li><b>1635</b>:Almargem do Bispo (Centro de Saúde) - Caneças</li></ul>">221</option>
#             <option value="<ul><li><b>1711</b>:Caneças (Esc. Secundária) - Pontinha (Metro)</li></ul>">224</option>
#             <option value="<ul><li><b>1524</b>:Casal do Cotão | Circular, via Tercena, São Marcos e Taguspark</li></ul>">23</option>
#             <option value="<ul><li><b>2631</b>:Casal de Cambra (C. Saúde) - Odivelas (Metro)</li><li><b>2632</b>:Casal de Cambra (C. Saúde) - Odivelas (Metro), via Bairro Sol Nascente</li></ul>">230</option>
#             <option value="<ul><li><b>2832</b>:Casal Novo - Lisboa (C. Militar), via Casal de Cambra</li><li><b>2833</b>:Pontinha (Metro) | Circular, via Casal Novo</li></ul>">236</option>
#             <option value="<ul><li><b>2627</b>:Mafra (Parque Desportivo) - Ribeira dos Tostões</li></ul>">239</option>
#             <option value="<ul><li><b>1226</b>:Massamá - Queluz (Estação)</li></ul>">24</option>
#             <option value="<ul><li><b>1513</b>:Amadora (Hospital) | Circular</li></ul>">25</option>
#             <option value="<ul><li><b>1201</b>:Alcolombal de Cima - Terrugem (Escola), via Sacário</li></ul>">253</option>
#             <option value="<ul><li><b>1255</b>:Rebanque - Portela de Sintra (Estação)</li></ul>">254</option>
#             <option value="<ul><li><b>1240</b>:Negrais - Portela de Sintra (Estação)</li></ul>">255</option>
#             <option value="<ul><li><b>1231</b>:Mem Martins (Esc. Ferreira Castro) - Coutinho Afonso</li></ul>">257</option>
#             <option value="<ul><li><b>1624</b>:Cascais (Terminal) - Portela de Sintra (Estação), via Azóia e Almoçageme</li></ul>">403</option>
#             <option value="<ul><li><b>1623</b>:Cascais (Terminal) - Portela de Sintra (Estação)</li></ul>">417</option>
#             <option value="<ul><li><b>1626</b>:CascaiShopping - Portela de Sintra (Estação)</li></ul>">417/418</option>
#             <option value="<ul><li><b>1621</b>:Bairro da Cruz Vermelha - Portela de Sintra (Estação)</li><li><b>1629</b>:Estoril (Estação) - Portela de Sintra (Estação)</li><li><b>1630</b>:Estoril (Estação) - Portela de Sintra (Estação), via Monte Estoril e Amoreira</li></ul>">418</option>
#             <option value="<ul><li><b>1252</b>:Portela de Sintra (Estação) | Circular</li></ul>">433</option>
#             <option value="<ul><li><b>1253</b>:Circuito Cabo da Roca - Portela de Sintra</li></ul>">435 (Adaptado)</option>
#             <option value="<ul><li><b>1206</b>:Algueirão-Mem Martins (Estação) - Portela de Sintra (Estação), via Tribunal</li></ul>">437</option>
#             <option value="<ul><li><b>1250</b>:Portela de Sintra (Estação) - Praia Grande</li></ul>">439 (Adaptado)</option>
#             <option value="<ul><li><b>1247</b>:Fontanelas - Portela de Sintra (Estação), via Janas</li></ul>">440 (Adaptado)</option>
#             <option value="<ul><li><b>1241</b>:Almoçageme (Av. Dr. B. Vasc. X R. Sto André) - Portela de Sintra (Estação)</li></ul>">441</option>
#             <option value="<ul><li><b>1254</b>:Circuito Praias - Portela de Sintra</li></ul>">441 (Adaptado)</option>
#             <option value="<ul><li><b>1246</b>:Fontanelas - Portela de Sintra (Estação), via Casal da Granja</li><li><b>1248</b>:Portela de Sintra (Estação) - Praia das Maçãs (Piscinas)</li></ul>">442</option>
#             <option value="<ul><li><b>1245</b>:Catribana - Portela de Sintra (Estação)</li></ul>">443</option>
#             <option value="<ul><li><b>1249</b>:Portela de Sintra (Estação) - Praia do Magoito</li></ul>">444</option>
#             <option value="<ul><li><b>1243</b>:Casais da Cabrela - Portela de Sintra (Estação)</li><li><b>1632</b>:Carvalhal - Portela de Sintra (Estação)</li></ul>">445</option>
#             <option value="<ul><li><b>1234</b>:ShopBus Mira Sintra</li></ul>">446</option>
#             <option value="<ul><li><b>1208</b>:Almargem do Bispo (Cemitério) - Portela de Sintra (Estação)</li><li><b>1235</b>:Covas de Ferro - Mercês (Estação)</li></ul>">447</option>
#             <option value="<ul><li><b>1214</b>:Cacém (Estação) - Alegro Sintra</li><li><b>1223</b>:ShopBus Cacém</li></ul>">448</option>
#             <option value="<ul><li><b>1210</b>:Bairro Fitares - Mem Martins (Esc. Secundária)</li></ul>">450</option>
#             <option value="<ul><li><b>1625</b>:Cascais (Terminal) - Rio de Mouro (Estação)</li></ul>">455</option>
#             <option value="<ul><li><b>1627</b>:CascaiShopping - Rio de Mouro (Estação)</li><li><b>1628</b>:Estoril (Estação) -  Rio de Mouro (Estação)</li><li><b>1631</b>:Estoril (Estação) - Rio de Mouro (Estação) | Direta</li></ul>">456</option>
#             <option value="<ul><li><b>1205</b>:Algueirão-Mem Martins (Estação) - Mem Martins (Esc. Secundária)</li></ul>">458</option>
#             <option value="<ul><li><b>1202</b>:Alegro Sintra - Mem Martins | Circular</li><li><b>1203</b>:Alegro Sintra - Rio de Mouro (Estação)</li><li><b>1207</b>:Algueirão-Mem Martins (Estação) - Rio de Mouro (Estação)</li><li><b>1251</b>:Portela de Sintra (Estação) - Rio de Mouro (Estação)</li></ul>">460</option>
#             <option value="<ul><li><b>1613</b>:Cacém (Estação) - Oeiras (Estação), via Trajouce</li><li><b>1618</b>:Abóboda (Auto Barão) - Cacém (Estação)</li><li><b>1622</b>:Cacém (Estação) - Carcavelos (Estação), via Trajouce</li></ul>">463</option>
#             <option value="<ul><li><b>1614</b>:Carcavelos (Estação) - Portela de Sintra (Estação)</li><li><b>1619</b>:Abóboda (Auto Barão) - Portela de Sintra (Estação)</li></ul>">467</option>
#             <option value="<ul><li><b>1615</b>:Carcavelos (Estação) - Rio de Mouro (Estação)</li><li><b>1620</b>:Abóboda (Auto Barão) - Rio de Mouro (Estação)</li></ul>">468</option>
#             <option value="<ul><li><b>2630</b>:Caneças (Esc. Secundária) | Circular</li></ul>">5</option>
#             <option value="<ul><li><b>2785</b>:Covas de Ferro - Lisboa (C. Grande)</li></ul>">813/818</option>
#             <option value="<ul><li><b>2620</b>:Covas de Ferro - Loures (Centro Saúde), via A-Dos-Calvos</li></ul>">813/822</option>
#             <option value="<ul><li><b>2621</b>:Covas de Ferro - Pinheiro de Loures</li></ul>">816</option>
#             <option value="<ul><li><b>2702</b>:Lisboa (C. Grande) - Pontinha (Metro)</li></ul>">931</option>
#          </select>
#
#
#      <br><br><details><summary>Linhas novas</summary><div><ul><li><b>1228</b>: Massamá (Estação) | Circular, via Belas</li><li><b>1232</b>: Rio de Mouro (Estação) | Circular, via Mem Martins</li><li><b>1242</b>: Cabrela - Várzea de Colares</li><li><b>1244</b>: Casal de Cambra - Portela de Sintra (Estação)</li><li><b>1509</b>: Amadora (Hospital) - Casal de Cambra (C. Saúde)</li><li><b>1516</b>: Casal de Cambra - Monte Abraão (Estação)</li><li><b>1520</b>: Algés (Terminal) - Cacém (Estação)</li><li><b>1521</b>: Algés (Terminal) - Cacém (Estação), via A5</li><li><b>1612</b>: Cacém (Estação) - Carcavelos (Estação)</li><li><b>1719</b>: Casal de Cambra - Lisboa (C. Militar)</li><li><b>1731</b>: Cacém (Estação) - Hospital São Francisco Xavier</li><li><b>2625</b>: Mafra - São João das Lampas</li></ul></div></details>
#
#     </div>
#
#     <div class="carreira-div" id="Vila Franca de Xira-div">
#         Linha antiga:
#         <select class="carreira" id="Vila Franca de Xira" onchange="mostraNova('Vila Franca de Xira')">
#             <option value="nada">-</option>
#             <option value="<ul><li><b>2310</b>:Bom Retiro - Carregado (Atral-CIPAN)</li><li><b>2313</b>:Carregado (Atral-CIPAN) - Vila Franca de Xira (Estação)</li><li><b>2314</b>:Castanheira do Ribatejo - Vila Franca de Xira (Estação)</li></ul>">14</option>
#             <option value="<ul><li><b>2303</b>:Alverca (Estação) - Arcena</li></ul>">153</option>
#             <option value="<ul><li><b>2928</b>:Casais da Granja - Vila Franca de Xira (Estação)</li></ul>">16</option>
#             <option value="<ul><li><b>2925</b>:Cadafais - Vila Franca de Xira (Terminal), via Bairro da Mata</li><li><b>2926</b>:Cadafais - Vila Franca de Xira (Terminal), via Cachoeiras</li></ul>">18</option>
#             <option value="<ul><li><b>2311</b>:Cachoeiras - Castanheira do Ribatejo</li><li><b>2312</b>:Cachoeiras - Vila Franca de Xira (Terminal)</li><li><b>2320</b>:Monte Gordo - Vila Franca de Xira (Estação)</li><li><b>2321</b>:Monte Gordo - Vila Franca de Xira (Terminal)</li><li><b>2927</b>:Cadafais - Vila Franca de Xira (Terminal), via Loja Nova</li></ul>">19</option>
#             <option value="<ul><li><b>2791</b>:Alverca (Z. Industrial) - Lisboa (C. Grande)</li></ul>">319</option>
#             <option value="<ul><li><b>2790</b>:Alverca (Estação) - Lisboa (C. Grande)</li><li><b>2793</b>:Forte da Casa - Lisboa (C. Grande)</li></ul>">320</option>
#             <option value="<ul><li><b>2319</b>:Forte da Casa | Circular</li></ul>">322</option>
#             <option value="<ul><li><b>2318</b>:Forte da Casa - Póvoa de Santa Iria (Estação) | Circular</li></ul>">323</option>
#             <option value="<ul><li><b>2323</b>:Póvoa de Santa Iria | Circular</li></ul>">324/326/328</option>
#             <option value="<ul><li><b>2536</b>:Póvoa de Santa Iria - Salvação | Circular</li></ul>">325</option>
#             <option value="<ul><li><b>2795</b>:Lisboa (C. Grande) - Quinta da Piedade</li></ul>">329</option>
#             <option value="<ul><li><b>2794</b>:Forte da Casa - Lisboa (Oriente)</li></ul>">330</option>
#             <option value="<ul><li><b>2530</b>:Alverca (Estação) - Bucelas, via Malvarosa</li></ul>">342</option>
#             <option value="<ul><li><b>2531</b>:Alverca (Estação) - Granja, via Casal das Areias</li><li><b>2533</b>:Alverca (Estação) - Santo Antão do Tojal, via Casal das Areias</li></ul>">346</option>
#             <option value="<ul><li><b>2792</b>:Arcena - Lisboa (Oriente)</li><li><b>2840</b>:Arcena - Lisboa (Oriente), via A1</li></ul>">347</option>
#             <option value="<ul><li><b>2537</b>:Póvoa de Santa Iria (Estação) - Santo Antão do Tojal</li></ul>">348/370</option>
#             <option value="<ul><li><b>2317</b>:Fonte Santa - Póvoa de Santa Iria (Estação), via Morgado</li><li><b>2326</b>:Póvoa de Santa Iria (Estação) - Vialonga</li></ul>">349</option>
#             <option value="<ul><li><b>2325</b>:Póvoa de Santa Iria (Estação) - Verdelho Ruivo</li></ul>">350</option>
#             <option value="<ul><li><b>2327</b>:Póvoa de Santa Iria (Estação) - Vialonga | Circular</li></ul>">351</option>
#             <option value="<ul><li><b>2797</b>:Lisboa (C. Grande) - Vialonga, via A8</li><li><b>2798</b>:Lisboa (C. Grande) - Vialonga, via A9 e A8</li></ul>">353</option>
#             <option value="<ul><li><b>2796</b>:Lisboa (C. Grande) - Vialonga</li></ul>">354</option>
#             <option value="<ul><li><b>2651</b>:Bucelas - Costa da Caparica (Terminal)</li></ul>">355</option>
#             <option value="<ul><li><b>2532</b>:Alverca (Estação) - Loures</li></ul>">360</option>
#             <option value="<ul><li><b>2538</b>:Póvoa de Santa Iria (Estação) - Santo Antão do Tojal, via Zambujal</li></ul>">370</option>
#             <option value="<ul><li><b>2307</b>:Arcena - Vila Franca de Xira (Terminal)</li></ul>">39</option>
#             <option value="<ul><li><b>2328</b>:Póvoa de Santa Iria (Qta Piedade) - Vila Franca de Xira (Terminal)</li></ul>">40</option>
#             <option value="<ul><li><b>2324</b>:Póvoa de Santa Iria - Vila Franca de Xira (Terminal)</li></ul>">40/41</option>
#             <option value="<ul><li><b>2302</b>:Alverca - Vila Franca de Xira (Terminal)</li></ul>">40/48</option>
#             <option value="<ul><li><b>2306</b>:Alverca (Estação) - Vila Franca de Xira (Terminal)</li></ul>">44</option>
#             <option value="<ul><li><b>2329</b>:Qta da Cruz de Pau - Sobralinho</li></ul>">45</option>
#             <option value="<ul><li><b>2331</b>:Torre de Cima e Capelas - Vila Franca de Xira (Hospital), via Povos</li><li><b>2332</b>:Vila Franca de Xira (Estação) - Vila Franca de Xira (Hospital)</li><li><b>2333</b>:Vila Franca de Xira (Estação) - Vila Franca de Xira (Hospital), via N1</li></ul>">49</option>
#             <option value="<ul><li><b>2316</b>:Cotovios - Vila Franca de Xira (Terminal)</li></ul>">50</option>
#             <option value="<ul><li><b>2301</b>:Alhandra - Bogalhão</li><li><b>2308</b>:Bogalhão - Vila Franca de Xira (Terminal)</li><li><b>2309</b>:Bogalhão - Vila Franca de Xira (Terminal), via Subserra</li><li><b>2330</b>:Subserra - Vila Franca de Xira (Terminal)</li></ul>">53</option>
#             <option value="<ul><li><b>2304</b>:Alverca (Estação) - Bulhaco</li></ul>">57</option>
#             <option value="<ul><li><b>2920</b>:A-do-Mourão - Alverca (Estação)</li></ul>">58</option>
#             <option value="<ul><li><b>2921</b>:Alhandra - Arruda dos Vinhos</li><li><b>2922</b>:Arruda dos Vinhos - Bulhaco</li></ul>">59</option>
#             <option value="<ul><li><b>2652</b>:Costa da Caparica (Terminal) - Forte da Casa</li></ul>">701</option>
#             <option value="<ul><li><b>2841</b>:Lisboa (C. Grande) - Sobralinho</li></ul>">72</option>
#          </select>
#
#
#      <br><br><details><summary>Linhas novas</summary><div><ul><li><b>2305</b>: Alverca (Estação) - Malvarosa | Circular</li><li><b>2315</b>: Castanheira do Ribatejo | Circular</li><li><b>2322</b>: Bolonha - Póvoa de Santa Iria (Estação)</li><li><b>2534</b>: Loures - Santa Iria da Azóia</li><li><b>2535</b>: Loures - Vila Franca de Xira</li><li><b>2539</b>: Sacavém (Estação) - Santa Iria da Azóia (Estação), via Portela da Azóia</li><li><b>2540</b>: Santa Iria da Azóia - Vialonga</li><li><b>2842</b>: Lisboa (C. Grande) - Vila Franca de Xira</li></ul></div></details>
#
#     </div>
#
#   </div>

# %%
novas = [('1530', 'Oeiras (Estação) - Queluz'), ('1601', 'Amadora Este (Metro) - Carcavelos (Praia)'), ('1602', 'Carcavelos (Praia) - Queluz')]

h = "<ul>\n"
for item in novas:
    h += f"   <li><b>{item[0]}</b>: {item[1]}</li>\n"
h += "</ul>\n"
    
print(h)
# Out:
# <ul>
#    <li><b>1530<b>: Oeiras (Estação) - Queluz</li>
#    <li><b>1601<b>: Amadora Este (Metro) - Carcavelos (Praia)</li>
#    <li><b>1602<b>: Carcavelos (Praia) - Queluz</li>
# </ul>
